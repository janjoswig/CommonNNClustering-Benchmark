# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Helper-function-definitions" data-toc-modified-id="Helper-function-definitions-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Helper function definitions</a></span></li><li><span><a href="#No-structure" data-toc-modified-id="No-structure-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>No structure</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Checks</a></span></li><li><span><a href="#Scan" data-toc-modified-id="Scan-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Scan</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Plots</a></span><ul class="toc-item"><li><span><a href="#Time" data-toc-modified-id="Time-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Time</a></span><ul class="toc-item"><li><span><a href="#Trends" data-toc-modified-id="Trends-2.3.1.1"><span class="toc-item-num">2.3.1.1&nbsp;&nbsp;</span>Trends</a></span></li></ul></li><li><span><a href="#Noise-level" data-toc-modified-id="Noise-level-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Noise level</a></span></li><li><span><a href="#Largest-cluster" data-toc-modified-id="Largest-cluster-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Largest cluster</a></span></li><li><span><a href="#Number-of-clusters" data-toc-modified-id="Number-of-clusters-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Number of clusters</a></span></li></ul></li></ul></li><li><span><a href="#Blobs" data-toc-modified-id="Blobs-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Blobs</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Checks</a></span></li><li><span><a href="#Scan" data-toc-modified-id="Scan-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Scan</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Plots</a></span><ul class="toc-item"><li><span><a href="#Time" data-toc-modified-id="Time-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Time</a></span></li><li><span><a href="#Noise-level" data-toc-modified-id="Noise-level-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Noise level</a></span></li><li><span><a href="#Largest-cluster" data-toc-modified-id="Largest-cluster-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Largest cluster</a></span></li><li><span><a href="#Number-of-clusters" data-toc-modified-id="Number-of-clusters-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>Number of clusters</a></span></li></ul></li></ul></li><li><span><a href="#Moons" data-toc-modified-id="Moons-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Moons</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Checks</a></span></li><li><span><a href="#Scan" data-toc-modified-id="Scan-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Scan</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Plots</a></span><ul class="toc-item"><li><span><a href="#Time" data-toc-modified-id="Time-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Time</a></span></li><li><span><a href="#Noise-level" data-toc-modified-id="Noise-level-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Noise level</a></span></li><li><span><a href="#Largest-cluster" data-toc-modified-id="Largest-cluster-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Largest cluster</a></span></li><li><span><a href="#Number-of-clusters" data-toc-modified-id="Number-of-clusters-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Number of clusters</a></span></li></ul></li></ul></li><li><span><a href="#Circles" data-toc-modified-id="Circles-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Circles</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Checks</a></span></li><li><span><a href="#Scan" data-toc-modified-id="Scan-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Scan</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Plots</a></span><ul class="toc-item"><li><span><a href="#Time" data-toc-modified-id="Time-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Time</a></span></li><li><span><a href="#Noise-level" data-toc-modified-id="Noise-level-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Noise level</a></span></li><li><span><a href="#Largest-cluster" data-toc-modified-id="Largest-cluster-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>Largest cluster</a></span></li><li><span><a href="#Number-of-clusters" data-toc-modified-id="Number-of-clusters-5.3.4"><span class="toc-item-num">5.3.4&nbsp;&nbsp;</span>Number of clusters</a></span></li></ul></li></ul></li><li><span><a href="#Varied" data-toc-modified-id="Varied-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Varied</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Checks</a></span></li><li><span><a href="#Scan" data-toc-modified-id="Scan-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Scan</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Plots</a></span><ul class="toc-item"><li><span><a href="#Time" data-toc-modified-id="Time-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Time</a></span></li><li><span><a href="#Noise-level" data-toc-modified-id="Noise-level-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>Noise level</a></span></li><li><span><a href="#Largest-cluster" data-toc-modified-id="Largest-cluster-6.3.3"><span class="toc-item-num">6.3.3&nbsp;&nbsp;</span>Largest cluster</a></span></li><li><span><a href="#Number-of-clusters" data-toc-modified-id="Number-of-clusters-6.3.4"><span class="toc-item-num">6.3.4&nbsp;&nbsp;</span>Number of clusters</a></span></li><li><span><a href="#Evaluation" data-toc-modified-id="Evaluation-6.3.5"><span class="toc-item-num">6.3.5&nbsp;&nbsp;</span>Evaluation</a></span></li></ul></li></ul></li><li><span><a href="#Aniso" data-toc-modified-id="Aniso-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Aniso</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Checks</a></span></li><li><span><a href="#Scan" data-toc-modified-id="Scan-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Scan</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Plots</a></span><ul class="toc-item"><li><span><a href="#Time" data-toc-modified-id="Time-7.3.1"><span class="toc-item-num">7.3.1&nbsp;&nbsp;</span>Time</a></span></li><li><span><a href="#Noise-level" data-toc-modified-id="Noise-level-7.3.2"><span class="toc-item-num">7.3.2&nbsp;&nbsp;</span>Noise level</a></span></li><li><span><a href="#Largest-cluster" data-toc-modified-id="Largest-cluster-7.3.3"><span class="toc-item-num">7.3.3&nbsp;&nbsp;</span>Largest cluster</a></span></li><li><span><a href="#Number-of-clusters" data-toc-modified-id="Number-of-clusters-7.3.4"><span class="toc-item-num">7.3.4&nbsp;&nbsp;</span>Number of clusters</a></span></li><li><span><a href="#Evaluation" data-toc-modified-id="Evaluation-7.3.5"><span class="toc-item-num">7.3.5&nbsp;&nbsp;</span>Evaluation</a></span></li></ul></li></ul></li><li><span><a href="#Backbone-dihedrals" data-toc-modified-id="Backbone-dihedrals-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Backbone dihedrals</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Checks</a></span></li><li><span><a href="#Scan" data-toc-modified-id="Scan-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Scan</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Plots</a></span><ul class="toc-item"><li><span><a href="#Time" data-toc-modified-id="Time-8.3.1"><span class="toc-item-num">8.3.1&nbsp;&nbsp;</span>Time</a></span></li><li><span><a href="#Noise-level" data-toc-modified-id="Noise-level-8.3.2"><span class="toc-item-num">8.3.2&nbsp;&nbsp;</span>Noise level</a></span></li><li><span><a href="#Largest-cluster" data-toc-modified-id="Largest-cluster-8.3.3"><span class="toc-item-num">8.3.3&nbsp;&nbsp;</span>Largest cluster</a></span></li><li><span><a href="#Number-of-clusters" data-toc-modified-id="Number-of-clusters-8.3.4"><span class="toc-item-num">8.3.4&nbsp;&nbsp;</span>Number of clusters</a></span></li><li><span><a href="#Evaluation" data-toc-modified-id="Evaluation-8.3.5"><span class="toc-item-num">8.3.5&nbsp;&nbsp;</span>Evaluation</a></span><ul class="toc-item"><li><span><a href="#Hierarchical-manual" data-toc-modified-id="Hierarchical-manual-8.3.5.1"><span class="toc-item-num">8.3.5.1&nbsp;&nbsp;</span>Hierarchical manual</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Cluster parameter scans

# %% [markdown]
# Remember to compile `cnnclustering` with `TRACE_CYTHON=0` if timings should be measured.

# %%
import json

import cnnclustering
from cnnclustering import cluster, plot
from cnnclustering import _fit, _primitive_types, _types
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.metrics import pairwise_distances
from sklearn.neighbors import KDTree
from sklearn.preprocessing import StandardScaler
from tqdm.notebook import tqdm

import helper

# %%
import importlib
importlib.reload(helper)
# Out:
# <module 'helper' from '/home/janjoswig/repo/CommonNNClustering/docsrc/benchmark/helper.py'>

# %%
mpl.rcParams["figure.dpi"] = 300

# %%
print(f"{'Python':>20} :  ", *sys.version.splitlines())
# Out:
#               Python :   3.8.8 (default, Mar 11 2021, 08:58:19)  [GCC 8.3.0]

# %%
print(f"cnnclustering :  ", cnnclustering.__version__)
# Out:
# cnnclustering :   0.4.1

# %% [markdown]
# ## Helper function definitions

# %%
neighbours_sorted_recipe = {
    "input_data": _types.InputDataExtNeighboursMemoryview,
    "neighbours_getter": _types.NeighboursGetterExtLookup,
    "neighbours": (_types.NeighboursExtVector, (5000,), {}),
    "neighbour_neighbours": (_types.NeighboursExtVector, (5000,), {}),
    "metric": _types.MetricExtDummy,
    "similarity_checker": _types.SimilarityCheckerExtScreensorted,
    "queue": _types.QueueExtFIFOQueue,
    "fitter": _fit.FitterExtBFS,
}

# %%
class RecordEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, cnnclustering.cluster.Record):
            return {
                "_type": "Record", 
                "n_points": obj.n_points,
                "radius_cutoff": obj.radius_cutoff,
                "cnn_cutoff": obj.cnn_cutoff,
                "member_cutoff": obj.member_cutoff,
                "max_clusters": obj.max_clusters,
                "n_clusters": obj.n_clusters,
                "ratio_largest": obj.ratio_largest,
                "ratio_noise": obj.ratio_noise,
                "execution_time": obj.execution_time,
                }
        return super().default(self, obj)

# %%
def as_Record(obj):
    try:
        _type = obj.pop('_type')
    except KeyError:
        _type = None

    if _type is None:
        return obj

    if _type == 'Record':
        return cnnclustering.cluster.Record(*obj.values())

    return obj

# %%
if "CLUSTERING_MAP" not in dir():
    CLUSTERING_MAP = {}

# %%
with open("records/records.json", "w") as fp:
    json.dump({k: v.summary._list for k, v in CLUSTERING_MAP.items()}, fp, cls=RecordEncoder, indent=4)

# %%
for scan_name, cl in CLUSTERING_MAP.items():
    print(scan_name, cl.summary[-1])
# Out:
# no_structure -----------------------------------------------------------------------------------------------
# #points   r         c         min       max       #clusters %largest  %noise    time
# 5000      0.690     150       20        None      1         1.000     0.000     00:00:0.217
# -----------------------------------------------------------------------------------------------
#
# blobs -----------------------------------------------------------------------------------------------
# #points   r         c         min       max       #clusters %largest  %noise    time
# 5000      0.590     150       20        None      2         0.667     0.000     00:00:0.563
# -----------------------------------------------------------------------------------------------
#
# moons -----------------------------------------------------------------------------------------------
# #points   r         c         min       max       #clusters %largest  %noise    time
# 5000      0.590     150       20        None      2         0.500     0.000     00:00:0.221
# -----------------------------------------------------------------------------------------------
#
# circles -----------------------------------------------------------------------------------------------
# #points   r         c         min       max       #clusters %largest  %noise    time
# 5000      0.590     150       20        None      2         0.500     0.000     00:00:0.602
# -----------------------------------------------------------------------------------------------
#
# varied -----------------------------------------------------------------------------------------------
# #points   r         c         min       max       #clusters %largest  %noise    time
# 5000      0.500     150       20        None      1         0.923     0.077     00:00:0.578
# -----------------------------------------------------------------------------------------------
#
# aniso -----------------------------------------------------------------------------------------------
# #points   r         c         min       max       #clusters %largest  %noise    time
# 5000      0.600     150       20        None      1         0.999     0.001     00:00:0.520
# -----------------------------------------------------------------------------------------------
#
# backbone -----------------------------------------------------------------------------------------------
# #points   r         c         min       max       #clusters %largest  %noise    time
# 5002      30.000    150       20        None      2         0.645     0.070     00:00:0.304
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# ## No structure

# %%
# The test data
data = helper.gen_no_structure_points((5000, 2))
distances = pairwise_distances(data)

fig, ax = plt.subplots(figsize=(1, 1))
ax.scatter(
    *data.T,
    s=0.5,
    
)

# %% [markdown]
# ### Checks

# %%
mpl.rcParams["font.size"] = 8
fig, ax = plt.subplots(figsize=(2, 2/1.618))
_ = plot.plot_histogram(ax, distances.flatten(), maxima=True, maxima_props={"order": 5})

# %%
print("Min: ", distances[distances > 0].min())
print("Max: ", distances.max())
# Out:
# Min:  0.00027307491487952
# Max:  4.842668307314774

# %%
min_n = []
max_n = []
mean_n = []
r_array = np.linspace(0, 5, 51)
for r in r_array:
    adjecancy = np.where((distances > 0) & (distances < r), 1, 0)
    n_neighbours = np.sum(adjecancy, axis=0)
    min_n.append(n_neighbours.min())
    max_n.append(n_neighbours.max())
    mean_n.append(n_neighbours.mean())

# %%
mpl.rcParams["font.size"] = 6
dist_hist_cutoff = 1.67

fig, (full_ax, zoom_ax) = plt.subplots(1, 2, figsize=(3, 2/1.618))
full_ax.plot(r_array, min_n)
full_ax.plot(r_array, max_n)
full_ax.plot(r_array, mean_n)
full_ax.axvline(dist_hist_cutoff, color="k", linestyle="--", linewidth=0.5)
intersection_index = np.argwhere(r_array < dist_hist_cutoff)[-1][0]
intersection_ticks = []
for intersection_list in [min_n, max_n, mean_n]:
    intersection_y = (intersection_list[intersection_index] + intersection_list[intersection_index + 1]) / 2
    intersection_ticks.append(intersection_y)
    full_ax.hlines(
        y=intersection_y,
        xmin=0, xmax=dist_hist_cutoff,
        color="k", linestyle="--", linewidth=0.5,
        transform=full_ax.transData,
        zorder=3
    )
full_ax.set_yticks((0, 5000))
full_ax.set_yticks(intersection_ticks, minor=True)
full_ax.set_yticklabels([int(t) for t in intersection_ticks], minor=True, fontsize="x-small")
full_ax.set_xlim(0, 5)

zoom_ax.plot(r_array, min_n)
zoom_ax.plot(r_array, max_n)
zoom_ax.plot(r_array, mean_n)
zoom_ax.set_xlim(0, 0.5)
zoom_ax.set_ylim(0, 100)
plt.tight_layout()

# %% [markdown]
# ### Scan

# %%
scan_name = "no_structure"
clustering = CLUSTERING_MAP[scan_name] = cluster.prepare_clustering(data)

# %%
for r in tqdm(np.arange(0.01, 0.7, 0.01)):
    neighbours = helper.compute_neighbours(data, r, sort=True)
    neighbours_clustering = cluster.prepare_clustering(
        neighbours,
        preparation_hook=cluster.prepare_neighbourhoods,
        **neighbours_sorted_recipe
    )

    for c in range(151):
        neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
        clustering.summary.append(neighbours_clustering.summary[-1])
# Out:
#   0%|          | 0/69 [00:00<?, ?it/s]

# %%
clustering.summary.to_DataFrame()

# %% [markdown]
# ### Plots

# %%
scan_name = "no_structure"
clustering = CLUSTERING_MAP[scan_name]

# %% [markdown]
# #### Time

# %%
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="execution_time",
    contour_props={
        "levels": 50,
        # "locator": mpl.ticker.LogLocator()
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax)
colorbar.set_label("time / s")

ax.set_xlim(0.01, 0.69)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# ##### Trends
#
# Clustering for fixed CommonNN cutoff $c$ is fast if the ...
#
#   - ... radius cutoff is small: majority of points has not enough neighbours and is immediately declared noise (no checking of the density criterion.
#   - ... radius cutoff is large: majority of points has a large share of the total number of points as neighbours and ends up in the same cluster (low number of re-checks)
#
# Generally clustering takes more time if the ...
#
#   - ... radius cutoff is large: more neighbours have to be retrieved; more neighbours have to be checked (assuming CommonNN cutoff is comparably low)
#   - ... CommoNN cutoff is large: checking takes more time; larger number of re-checks (assuming CommonNN cutoff is comparably low)

# %% [markdown]
# #### Noise level

# %%
# Noise level
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax, quantity="ratio_noise",
    contour_props={
        "levels": 100,
        "vmin": 0,
        "vmax": 1,
    },
    # convert=lambda x: x * 100
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("noise / %")

ax.set_xlim(0.01, 0.69)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Largest cluster

# %%
# Largest cluster
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_largest",
    contour_props={
        "levels": 100,
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("largest / %")

ax.set_xlim(0.01, 0.69)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Number of clusters

# %%
# Number of clusters
show_n = 10

fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="n_clusters",
    contour_props={
        "levels": np.arange(-0.5, show_n + 1.5, 1),
        "vmin": 0,
        "vmax": show_n,
        "extend": "max"
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=range(0, show_n + 1, 2))
colorbar.set_label("# clusters")

ax.set_xlim(0.01, 0.69)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# ## Blobs

# %%
# The test data
data = helper.gen_blobs_points((5000, 2))
distances = pairwise_distances(data)

fig, ax = plt.subplots(figsize=(1, 1))
ax.scatter(
    *data.T,
    s=0.5,
    
)

# %% [markdown]
# ### Checks

# %%
mpl.rcParams["font.size"] = 8
fig, ax = plt.subplots(figsize=(2, 2/1.618))
_ = plot.plot_histogram(ax, distances.flatten(), maxima=True, maxima_props={"order": 5})

# %%
print("Min: ", distances[distances > 0].min())
print("Max: ", distances.max())
# Out:
# Min:  4.422092256111229e-05
# Max:  4.097490617525474

# %%
min_n = []
max_n = []
mean_n = []
r_array = np.linspace(0, 5, 51)
for r in r_array:
    adjecancy = np.where((distances > 0) & (distances < r), 1, 0)
    n_neighbours = np.sum(adjecancy, axis=0)
    min_n.append(n_neighbours.min())
    max_n.append(n_neighbours.max())
    mean_n.append(n_neighbours.mean())

# %%
mpl.rcParams["font.size"] = 6
dist_hist_cutoff = 1.13

fig, (full_ax, zoom_ax) = plt.subplots(1, 2, figsize=(3, 2/1.618))
full_ax.plot(r_array, min_n)
full_ax.plot(r_array, max_n)
full_ax.plot(r_array, mean_n)
full_ax.axvline(dist_hist_cutoff, color="k", linestyle="--", linewidth=0.5)
intersection_index = np.argwhere(r_array < dist_hist_cutoff)[-1][0]
intersection_ticks = []
for intersection_list in [min_n, max_n, mean_n]:
    intersection_y = (intersection_list[intersection_index] + intersection_list[intersection_index + 1]) / 2
    intersection_ticks.append(intersection_y)
    full_ax.hlines(
        y=intersection_y,
        xmin=0, xmax=dist_hist_cutoff,
        color="k", linestyle="--", linewidth=0.5,
        transform=full_ax.transData,
        zorder=3
    )
full_ax.set_yticks((0, 5000))
full_ax.set_yticks(intersection_ticks, minor=True)
full_ax.set_yticklabels([int(t) for t in intersection_ticks], minor=True, fontsize="x-small")
full_ax.set_xlim(0, 5)

zoom_ax.plot(r_array, min_n)
zoom_ax.plot(r_array, max_n)
zoom_ax.plot(r_array, mean_n)
zoom_ax.set_xlim(0, 0.5)
zoom_ax.set_ylim(0, 100)
plt.tight_layout()

# %% [markdown]
# ### Scan

# %%
scan_name = "blobs"
clustering = CLUSTERING_MAP[scan_name] = cluster.prepare_clustering(data)

# %%
for r in tqdm(np.arange(0.01, 0.6, 0.01)):
    neighbours = helper.compute_neighbours(data, r, sort=True)
    neighbours_clustering = cluster.prepare_clustering(
        neighbours,
        preparation_hook=cluster.prepare_neighbourhoods,
        **neighbours_sorted_recipe
    )

    for c in range(151):
        neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
        clustering.summary.append(neighbours_clustering.summary[-1])
# Out:
#   0%|          | 0/59 [00:00<?, ?it/s]

# %% [markdown]
# ### Plots

# %%
scan_name = "blobs"
clustering = CLUSTERING_MAP[scan_name]

# %% [markdown]
# #### Time

# %%
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="execution_time",
    contour_props={
        "levels": 50,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax)
colorbar.set_label("time / s")

ax.set_xlim(0.01, 0.59)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Noise level

# %%
# Noise level
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_noise",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("noise / %")

ax.set_xlim(0.01, 0.59)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Largest cluster

# %%
# Largest cluster
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_largest",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("largest / %")

ax.set_xlim(0.01, 0.59)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Number of clusters

# %%
# Number of clusters
show_n = 10

fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="n_clusters",
    contour_props={
        "levels": np.arange(-0.5, show_n + 1.5, 1),
        "vmin": 0,
        "vmax": show_n,
        "extend": "max"
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=range(0, show_n + 1, 2))
colorbar.set_label("# clusters")

ax.set_xlim(0.01, 0.59)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# ## Moons

# %%
# The test data
data = helper.gen_moons_points(
    (5000, 2),
    noise=.05
)
distances = pairwise_distances(data)

fig, ax = plt.subplots(figsize=(1, 1))
ax.scatter(
    *data.T,
    s=0.5,
)

# %% [markdown]
# ### Checks

# %%
mpl.rcParams["font.size"] = 8
fig, ax = plt.subplots(figsize=(2, 2/1.618))
_ = plot.plot_histogram(ax, distances.flatten(), maxima=True, maxima_props={"order": 5})

# %%
print("Min: ", distances[distances > 0].min())
print("Max: ", distances.max())
# Out:
# Min:  9.927475001661245e-05
# Max:  3.892931346774215

# %%
min_n = []
max_n = []
mean_n = []
r_array = np.linspace(0, 5, 51)
for r in r_array:
    adjecancy = np.where((distances > 0) & (distances < r), 1, 0)
    n_neighbours = np.sum(adjecancy, axis=0)
    min_n.append(n_neighbours.min())
    max_n.append(n_neighbours.max())
    mean_n.append(n_neighbours.mean())

# %%
mpl.rcParams["font.size"] = 6
dist_hist_cutoff = 1.19

fig, (full_ax, zoom_ax) = plt.subplots(1, 2, figsize=(3, 2/1.618))
full_ax.plot(r_array, min_n)
full_ax.plot(r_array, max_n)
full_ax.plot(r_array, mean_n)
full_ax.axvline(dist_hist_cutoff, color="k", linestyle="--", linewidth=0.5)
intersection_index = np.argwhere(r_array < dist_hist_cutoff)[-1][0]
intersection_ticks = []
for intersection_list in [min_n, max_n, mean_n]:
    intersection_y = (intersection_list[intersection_index] + intersection_list[intersection_index + 1]) / 2
    intersection_ticks.append(intersection_y)
    full_ax.hlines(
        y=intersection_y,
        xmin=0, xmax=dist_hist_cutoff,
        color="k", linestyle="--", linewidth=0.5,
        transform=full_ax.transData,
        zorder=3
    )
full_ax.set_yticks((0, 5000))
full_ax.set_yticks(intersection_ticks, minor=True)
full_ax.set_yticklabels([int(t) for t in intersection_ticks], minor=True, fontsize="x-small")
full_ax.set_xlim(0, 5)

zoom_ax.plot(r_array, min_n)
zoom_ax.plot(r_array, max_n)
zoom_ax.plot(r_array, mean_n)
zoom_ax.set_xlim(0, 0.5)
zoom_ax.set_ylim(0, 100)
plt.tight_layout()

# %% [markdown]
# ### Scan

# %%
scan_name = "moons"
clustering = CLUSTERING_MAP[scan_name] = cluster.prepare_clustering(data)

# %%
for r in tqdm(np.arange(0.01, 0.6, 0.01)):
    neighbours = helper.compute_neighbours(data, r, sort=True)
    neighbours_clustering = cluster.prepare_clustering(
        neighbours,
        preparation_hook=cluster.prepare_neighbourhoods,
        **neighbours_sorted_recipe
    )

    for c in range(151):
        neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
        clustering.summary.append(neighbours_clustering.summary[-1])
# Out:
#   0%|          | 0/59 [00:00<?, ?it/s]

# %% [markdown]
# ### Plots

# %%
scan_name = "moons"
clustering = CLUSTERING_MAP[scan_name]

# %% [markdown]
# #### Time

# %%
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="execution_time",
    contour_props={
        "levels": 50,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax)
colorbar.set_label("time / s")

ax.set_xlim(0.01, 0.59)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Noise level

# %%
# Noise level
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_noise",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("noise / %")

ax.set_xlim(0.01, 0.59)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Largest cluster

# %%
# Largest cluster
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_largest",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("largest / %")

ax.set_xlim(0.01, 0.59)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Number of clusters

# %%
# Number of clusters
show_n = 10

fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="n_clusters",
    contour_props={
        "levels": np.arange(-0.5, show_n + 1.5, 1),
        "vmin": 0,
        "vmax": show_n,
        "extend": "max"
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=range(0, show_n + 1, 2))
colorbar.set_label("# clusters")

ax.set_xlim(0.01, 0.59)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# ## Circles

# %%
# The test data
data = helper.gen_circles_points(
    (5000, 2),
    factor=.5,
    noise=.05
)
distances = pairwise_distances(data)

fig, ax = plt.subplots(figsize=(1, 1))
ax.scatter(
    *data.T,
    s=0.5,
)

# %% [markdown]
# ### Checks

# %%
mpl.rcParams["font.size"] = 8
fig, ax = plt.subplots(figsize=(2, 2/1.618))
_ = plot.plot_histogram(ax, distances.flatten(), maxima=True, maxima_props={"order": 5})

# %%
print("Min: ", distances[distances > 0].min())
print("Max: ", distances.max())
# Out:
# Min:  0.0001264168234122532
# Max:  4.199475414902217

# %%
min_n = []
max_n = []
mean_n = []
r_array = np.linspace(0, 5, 51)
for r in r_array:
    adjecancy = np.where((distances > 0) & (distances < r), 1, 0)
    n_neighbours = np.sum(adjecancy, axis=0)
    min_n.append(n_neighbours.min())
    max_n.append(n_neighbours.max())
    mean_n.append(n_neighbours.mean())

# %%
mpl.rcParams["font.size"] = 6
dist_hist_cutoff = 1.03

fig, (full_ax, zoom_ax) = plt.subplots(1, 2, figsize=(3, 2/1.618))
full_ax.plot(r_array, min_n)
full_ax.plot(r_array, max_n)
full_ax.plot(r_array, mean_n)
full_ax.axvline(dist_hist_cutoff, color="k", linestyle="--", linewidth=0.5)
intersection_index = np.argwhere(r_array < dist_hist_cutoff)[-1][0]
intersection_ticks = []
for intersection_list in [min_n, max_n, mean_n]:
    intersection_y = (intersection_list[intersection_index] + intersection_list[intersection_index + 1]) / 2
    intersection_ticks.append(intersection_y)
    full_ax.hlines(
        y=intersection_y,
        xmin=0, xmax=dist_hist_cutoff,
        color="k", linestyle="--", linewidth=0.5,
        transform=full_ax.transData,
        zorder=3
    )
full_ax.set_yticks((0, 5000))
full_ax.set_yticks(intersection_ticks, minor=True)
full_ax.set_yticklabels([int(t) for t in intersection_ticks], minor=True, fontsize="x-small")
full_ax.set_xlim(0, 5)

zoom_ax.plot(r_array, min_n)
zoom_ax.plot(r_array, max_n)
zoom_ax.plot(r_array, mean_n)
zoom_ax.set_xlim(0, 0.5)
zoom_ax.set_ylim(0, 100)
plt.tight_layout()

# %% [markdown]
# ### Scan

# %%
scan_name = "circles"
clustering = CLUSTERING_MAP[scan_name] = cluster.prepare_clustering(data)

# %%
for r in tqdm(np.arange(0.01, 0.6, 0.01)):
    neighbours = helper.compute_neighbours(data, r, sort=True)
    neighbours_clustering = cluster.prepare_clustering(
        neighbours,
        preparation_hook=cluster.prepare_neighbourhoods,
        **neighbours_sorted_recipe
    )

    for c in range(151):
        neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
        clustering.summary.append(neighbours_clustering.summary[-1])
# Out:
#   0%|          | 0/59 [00:00<?, ?it/s]

# %% [markdown]
# ### Plots

# %%
scan_name = "circles"
clustering = CLUSTERING_MAP[scan_name]

# %% [markdown]
# #### Time

# %%
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="execution_time",
    contour_props={
        "levels": 50,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax)
colorbar.set_label("time / s")

ax.set_xlim(0.01, 0.59)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Noise level

# %%
# Noise level
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_noise",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("noise / %")

ax.set_xlim(0.01, 0.59)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Largest cluster

# %%
# Largest cluster
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_largest",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("largest / %")

ax.set_xlim(0.01, 0.59)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Number of clusters

# %%
# Number of clusters
show_n = 10

fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="n_clusters",
    contour_props={
        "levels": np.arange(-0.5, show_n + 1.5, 1),
        "vmin": 0,
        "vmax": show_n,
        "extend": "max"
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=range(0, show_n + 1, 2))
colorbar.set_label("# clusters")

ax.set_xlim(0.01, 0.59)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# ## Varied

# %%
# The test data
data = helper.gen_blobs_points(
    (5000, 2),
    random_state=170,
    cluster_std=[1.0, 2.5, 0.5],
)
distances = pairwise_distances(data)

fig, ax = plt.subplots(figsize=(1, 1))
ax.scatter(
    *data.T,
    s=0.5,
)

# %% [markdown]
# ### Checks

# %%
mpl.rcParams["font.size"] = 8
fig, ax = plt.subplots(figsize=(2, 2/1.618))
_ = plot.plot_histogram(ax, distances.flatten(), maxima=True, maxima_props={"order": 5})

# %%
print("Min: ", distances[distances > 0].min())
print("Max: ", distances.max())
# Out:
# Min:  0.00021837824482724168
# Max:  5.457257351668825

# %%
min_n = []
max_n = []
mean_n = []
r_array = np.linspace(0, 5, 51)
for r in r_array:
    adjecancy = np.where((distances > 0) & (distances < r), 1, 0)
    n_neighbours = np.sum(adjecancy, axis=0)
    min_n.append(n_neighbours.min())
    max_n.append(n_neighbours.max())
    mean_n.append(n_neighbours.mean())

# %%
mpl.rcParams["font.size"] = 6
dist_hist_cutoff = 1.56

fig, (full_ax, zoom_ax) = plt.subplots(1, 2, figsize=(3, 2/1.618))
full_ax.plot(r_array, min_n)
full_ax.plot(r_array, max_n)
full_ax.plot(r_array, mean_n)
full_ax.axvline(dist_hist_cutoff, color="k", linestyle="--", linewidth=0.5)
intersection_index = np.argwhere(r_array < dist_hist_cutoff)[-1][0]
intersection_ticks = []
for intersection_list in [min_n, max_n, mean_n]:
    intersection_y = (intersection_list[intersection_index] + intersection_list[intersection_index + 1]) / 2
    intersection_ticks.append(intersection_y)
    full_ax.hlines(
        y=intersection_y,
        xmin=0, xmax=dist_hist_cutoff,
        color="k", linestyle="--", linewidth=0.5,
        transform=full_ax.transData,
        zorder=3
    )
full_ax.set_yticks((0, 5000))
full_ax.set_yticks(intersection_ticks, minor=True)
full_ax.set_yticklabels([int(t) for t in intersection_ticks], minor=True, fontsize="x-small")
full_ax.set_xlim(0, 5)

zoom_ax.plot(r_array, min_n)
zoom_ax.plot(r_array, max_n)
zoom_ax.plot(r_array, mean_n)
zoom_ax.set_xlim(0, 0.5)
zoom_ax.set_ylim(0, 100)
plt.tight_layout()

# %% [markdown]
# ### Scan

# %%
scan_name = "varied"
clustering = CLUSTERING_MAP[scan_name] = cluster.prepare_clustering(data)

# %%
for r in tqdm(np.arange(0.01, 0.51, 0.01)):
    neighbours = helper.compute_neighbours(data, r, sort=True)
    neighbours_clustering = cluster.prepare_clustering(
        neighbours,
        preparation_hook=cluster.prepare_neighbourhoods,
        **neighbours_sorted_recipe
    )

    for c in range(151):
        neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
        clustering.summary.append(neighbours_clustering.summary[-1])
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# ### Plots

# %%
scan_name = "varied"
clustering = CLUSTERING_MAP[scan_name]

# %%
clustering.summary.to_DataFrame()
# Out:
#       n_points  radius_cutoff  cnn_cutoff  member_cutoff  max_clusters  \
# 0         5000           0.01           0             20          <NA>
# 1         5000           0.01           1             20          <NA>
# 2         5000           0.01           2             20          <NA>
# 3         5000           0.01           3             20          <NA>
# 4         5000           0.01           4             20          <NA>
# ...        ...            ...         ...            ...           ...
# 7545      5000           0.50         146             20          <NA>
# 7546      5000           0.50         147             20          <NA>
# 7547      5000           0.50         148             20          <NA>
# 7548      5000           0.50         149             20          <NA>
# 7549      5000           0.50         150             20          <NA>
#
#       n_clusters  ratio_largest  ratio_noise  execution_time
# 0              5         0.0818       0.8856        0.001223
# 1              6         0.0198       0.9528        0.001058
# 2              2         0.0174       0.9784        0.000993
# 3              1         0.0108       0.9892        0.000940
# 4              1         0.0086       0.9914        0.000867
# ...          ...            ...          ...             ...
# 7545           1         0.9252       0.0748        0.555526
# 7546           1         0.9252       0.0748        0.568364
# 7547           1         0.9242       0.0758        0.595478
# 7548           1         0.9238       0.0762        0.584090
# 7549           1         0.9228       0.0772        0.578298
#
# [7550 rows x 9 columns]

# %% [markdown]
# #### Time

# %%
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="execution_time",
    contour_props={
        "levels": 50,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax)
colorbar.set_label("time / s")

ax.set_xlim(0.01, 0.5)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Noise level

# %%
# Noise level
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_noise",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("noise / %")
ax.set_xlim(0.01, 0.5)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Largest cluster

# %%
# Largest cluster
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_largest",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("largest / %")
ax.set_xlim(0.01, 0.5)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Number of clusters

# %%
# Number of clusters
show_n = 10

fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="n_clusters",
    contour_props={
        "levels": np.arange(-0.5, show_n + 1.5, 1),
        "vmin": 0,
        "vmax": show_n,
        "extend": "max"
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=range(0, show_n + 1, 2))
colorbar.set_label("# clusters")
ax.set_xlim(0.01, 0.5)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Evaluation

# %%
r = 0.2
c = 50

neighbours = helper.compute_neighbours(data, r, sort=True)
neighbours_clustering = cluster.prepare_clustering(
    neighbours,
    preparation_hook=cluster.prepare_neighbourhoods,
    **neighbours_sorted_recipe
)

neighbours_clustering.fit(0., c, member_cutoff=20, v=False)
clustering._labels = neighbours_clustering._labels

# %%
fig, ax = plt.subplots(figsize=(2, 2/1.618))
clustering.evaluate(ax=ax)
# Out:
# (<Figure size 600x370.828 with 1 Axes>,
#  <AxesSubplot:xlabel='$x$', ylabel='$y$'>)

# %% [markdown]
# ## Aniso

# %%
# The test data
data = helper.gen_blobs_points(
    (5000, 2),
    random_state=170,
    
)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
data = np.dot(data, transformation)

distances = pairwise_distances(data)

fig, ax = plt.subplots(figsize=(1, 1))
ax.scatter(
    *data.T,
    s=0.5,
)

# %% [markdown]
# ### Checks

# %%
mpl.rcParams["font.size"] = 8
fig, ax = plt.subplots(figsize=(2, 2/1.618))
_ = plot.plot_histogram(ax, distances.flatten(), maxima=True, maxima_props={"order": 5})

# %%
print("Min: ", distances[distances > 0].min())
print("Max: ", distances.max())
# Out:
# Min:  0.0001934117086504001
# Max:  3.6222164035708793

# %%
min_n = []
max_n = []
mean_n = []
r_array = np.linspace(0, 4, 41)
for r in r_array:
    adjecancy = np.where((distances > 0) & (distances < r), 1, 0)
    n_neighbours = np.sum(adjecancy, axis=0)
    min_n.append(n_neighbours.min())
    max_n.append(n_neighbours.max())
    mean_n.append(n_neighbours.mean())

# %%
mpl.rcParams["font.size"] = 6
dist_hist_cutoff = 0.67

fig, (full_ax, zoom_ax) = plt.subplots(1, 2, figsize=(3, 2/1.618))
full_ax.plot(r_array, min_n)
full_ax.plot(r_array, max_n)
full_ax.plot(r_array, mean_n)
full_ax.axvline(dist_hist_cutoff, color="k", linestyle="--", linewidth=0.5)
intersection_index = np.argwhere(r_array < dist_hist_cutoff)[-1][0]
intersection_ticks = []
for intersection_list in [min_n, max_n, mean_n]:
    intersection_y = (intersection_list[intersection_index] + intersection_list[intersection_index + 1]) / 2
    intersection_ticks.append(intersection_y)
    full_ax.hlines(
        y=intersection_y,
        xmin=0, xmax=dist_hist_cutoff,
        color="k", linestyle="--", linewidth=0.5,
        transform=full_ax.transData,
        zorder=3
    )
full_ax.set_yticks((0, 5000))
full_ax.set_yticks(intersection_ticks, minor=True)
full_ax.set_yticklabels([int(t) for t in intersection_ticks], minor=True, fontsize="x-small")
full_ax.set_xlim(0, 5)

zoom_ax.plot(r_array, min_n)
zoom_ax.plot(r_array, max_n)
zoom_ax.plot(r_array, mean_n)
zoom_ax.set_xlim(0, 0.5)
zoom_ax.set_ylim(0, 100)
plt.tight_layout()

# %% [markdown]
# ### Scan

# %%
scan_name = "aniso"
clustering = CLUSTERING_MAP[scan_name] = cluster.prepare_clustering(data)

# %%
for r in tqdm(np.arange(0.01, 0.61, 0.01)):
    neighbours = helper.compute_neighbours(data, r, sort=True)
    neighbours_clustering = cluster.prepare_clustering(
        neighbours,
        preparation_hook=cluster.prepare_neighbourhoods,
        **neighbours_sorted_recipe
    )

    for c in range(151):
        neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
        clustering.summary.append(neighbours_clustering.summary[-1])
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]

# %% [markdown]
# ### Plots

# %%
scan_name = "aniso"
clustering = CLUSTERING_MAP[scan_name]

# %% [markdown]
# #### Time

# %%
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="execution_time",
    contour_props={
        "levels": 50,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax)
colorbar.set_label("time / s")

ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Noise level

# %%
# Noise level
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_noise",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("noise / %")
ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %%
# Noise level
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_noise",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("noise / %")
ax.set_xlim(0.01, 0.13)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Largest cluster

# %%
# Largest cluster
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_largest",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("largest / %")
ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Number of clusters

# %%
# Number of clusters
show_n = 10

fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="n_clusters",
    contour_props={
        "levels": np.arange(-0.5, show_n + 1.5, 1),
        "vmin": 0,
        "vmax": show_n,
        "extend": "max"
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=range(0, show_n + 1, 2))
colorbar.set_label("# clusters")
ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Evaluation

# %%
r = 0.13
c = 50

neighbours = helper.compute_neighbours(data, r, sort=True)
neighbours_clustering = cluster.prepare_clustering(
    neighbours,
    preparation_hook=cluster.prepare_neighbourhoods,
    **neighbours_sorted_recipe
)

neighbours_clustering.fit(0., c, member_cutoff=20, v=False)
clustering._labels = neighbours_clustering._labels

# %%
fig, ax = plt.subplots(figsize=(2, 2/1.618))
clustering.evaluate(ax=ax)
# Out:
# (<Figure size 1800x1200 with 1 Axes>, <AxesSubplot:xlabel='$x$', ylabel='$y$'>)

# %% [markdown]
# ## Backbone dihedrals

# %%
# The test data
data_path = pathlib.Path("/home/janjoswig/repo/CommonNNClustering/test/integration/test_procedures/backbone_dihedrals.npy")
data = np.load(data_path)
n_points = data.shape[0]

bounds = np.array([360, 360])
distances = np.zeros((n_points, n_points))
for i in range(n_points):
    for j in range(i + 1, n_points):
        d = np.absolute(data[i] - data[j]) % bounds
        d = np.where(d > (bounds / 2), bounds - d, d)
        distances[i, j] = np.sqrt(np.power(d, 2).sum())
        
tril = np.tril_indices_from(distances)
distances[tril] = distances.T[tril]
        
fig, ax = plt.subplots(figsize=(1, 1))
ax.scatter(
    *data.T,
    s=0.5,
)

# %%
data_alt = _types.InputDataExtPointsMemoryview(data)
metric = _types.MetricExtEuclideanPeriodicReduced(np.array([360, 360], dtype=float))

distances_alt = np.zeros((n_points, n_points))
for i in range(n_points):
    for j in range(i + 1, n_points):
        distances_alt[i, j] = np.sqrt(metric.calc_distance(i, j, data_alt))
        
tril = np.tril_indices_from(distances_alt)
distances_alt[tril] = distances_alt.T[tril]

# %% [markdown]
# ### Checks

# %%
mpl.rcParams["font.size"] = 8
fig, ax = plt.subplots(figsize=(2, 2/1.618))
_ = plot.plot_histogram(ax, distances.flatten(), maxima=True, maxima_props={"order": 5})
_ = plot.plot_histogram(ax, distances_alt.flatten(), maxima=True, maxima_props={"order": 5})

# %%
print("Min: ", distances[distances > 0].min())
print("Max: ", distances.max())
# Out:
# Min:  0.006020797289395393
# Max:  254.29970200612834

# %%
min_n = []
max_n = []
mean_n = []
r_array = np.linspace(0, 180, 37)
for r in r_array:
    adjecancy = np.where((distances > 0) & (distances < r), 1, 0)
    n_neighbours = np.sum(adjecancy, axis=0)
    min_n.append(n_neighbours.min())
    max_n.append(n_neighbours.max())
    mean_n.append(n_neighbours.mean())

# %%
mpl.rcParams["font.size"] = 6
dist_hist_cutoff = 24

fig, (full_ax, zoom_ax) = plt.subplots(1, 2, figsize=(3, 2/1.618))
full_ax.plot(r_array, min_n)
full_ax.plot(r_array, max_n)
full_ax.plot(r_array, mean_n)
full_ax.axvline(dist_hist_cutoff, color="k", linestyle="--", linewidth=0.5)
intersection_index = np.argwhere(r_array < dist_hist_cutoff)[-1][0]
intersection_ticks = []
for intersection_list in [min_n, max_n, mean_n]:
    intersection_y = (intersection_list[intersection_index] + intersection_list[intersection_index + 1]) / 2
    intersection_ticks.append(intersection_y)
    full_ax.hlines(
        y=intersection_y,
        xmin=0, xmax=dist_hist_cutoff,
        color="k", linestyle="--", linewidth=0.5,
        transform=full_ax.transData,
        zorder=3
    )
full_ax.set_yticks((0, 5000))
full_ax.set_yticks(intersection_ticks, minor=True)
full_ax.set_yticklabels([int(t) for t in intersection_ticks], minor=True, fontsize="x-small")
full_ax.set_xlim(0, 180)

zoom_ax.plot(r_array, min_n)
zoom_ax.plot(r_array, max_n)
zoom_ax.plot(r_array, mean_n)
zoom_ax.set_xlim(0, 24)
zoom_ax.set_ylim(0, 100)
plt.tight_layout()

# %% [markdown]
# ### Scan

# %%
scan_name = "backbone"
clustering = CLUSTERING_MAP[scan_name] = cluster.prepare_clustering(data)

# %%
for r in tqdm(np.arange(1, 31, 1)):
    
    neighbours = [np.where((d > 0) & (d < r))[0] for d in distances]
    for n in neighbours:
        n.sort()
        
    neighbours_clustering = cluster.prepare_clustering(
        neighbours,
        preparation_hook=cluster.prepare_neighbourhoods,
        **neighbours_sorted_recipe
    )
    neighbours_clustering._neighbours_getter.is_selfcounting = False

    for c in range(151):
        neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
        clustering.summary.append(neighbours_clustering.summary[-1])
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %% [markdown]
# ### Plots

# %%
scan_name = "backbone"
clustering = CLUSTERING_MAP[scan_name]

# %% [markdown]
# #### Time

# %%
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="execution_time",
    contour_props={
        "levels": 50,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax)
colorbar.set_label("time / s")

ax.set_xlim(1, 30)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Noise level

# %%
# Noise level
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_noise",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("noise / %")

ax.set_xlim(1, 30)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Largest cluster

# %%
# Largest cluster
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_largest",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("largest / %")

ax.set_xlim(1, 30)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Number of clusters

# %%
# Number of clusters
show_n = 10

fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="n_clusters",
    contour_props={
        "levels": np.arange(-0.5, show_n + 1.5, 1),
        "vmin": 0,
        "vmax": show_n,
        "extend": "max"
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=range(0, show_n + 1, 2))
colorbar.set_label("# clusters")

ax.set_xlim(1, 30)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Evaluation

# %%
r = 20
c = 30

neighbours = [np.where((d > 0) & (d < r))[0] for d in distances]
for n in neighbours:
    n.sort()
        
neighbours_clustering = cluster.prepare_clustering(
    neighbours,
    preparation_hook=cluster.prepare_neighbourhoods,
    **neighbours_sorted_recipe
)
neighbours_clustering._neighbours_getter.is_selfcounting = False

neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
clustering._labels = neighbours_clustering._labels

# %%
fig, ax = plt.subplots(figsize=(2, 2/1.618))
clustering.evaluate(ax=ax, ax_props={"xlim": (-180, 180), "ylim": (-180, 180), "aspect": "equal"})
# Out:
# (<Figure size 600x370.828 with 1 Axes>,
#  <AxesSubplot:xlabel='$x$', ylabel='$y$'>)

# %%
r = 8.5
c = 30

neighbours = [np.where((d > 0) & (d < r))[0] for d in distances]
for n in neighbours:
    n.sort()
        
neighbours_clustering = cluster.prepare_clustering(
    neighbours,
    preparation_hook=cluster.prepare_neighbourhoods,
    **neighbours_sorted_recipe
)
neighbours_clustering._neighbours_getter.is_selfcounting = False

neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
clustering._labels = neighbours_clustering._labels

# %%
fig, ax = plt.subplots(figsize=(2, 2/1.618))
clustering.evaluate(ax=ax, ax_props={"xlim": (-180, 180), "ylim": (-180, 180), "aspect": "equal"})
# Out:
# (<Figure size 600x370.828 with 1 Axes>,
#  <AxesSubplot:xlabel='$x$', ylabel='$y$'>)

# %%
r = 5
c = 30

neighbours = [np.where((d > 0) & (d < r))[0] for d in distances]
for n in neighbours:
    n.sort()
        
neighbours_clustering = cluster.prepare_clustering(
    neighbours,
    preparation_hook=cluster.prepare_neighbourhoods,
    **neighbours_sorted_recipe
)
neighbours_clustering._neighbours_getter.is_selfcounting = False

neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
clustering._labels = neighbours_clustering._labels

# %%
fig, ax = plt.subplots(figsize=(2, 2/1.618))
clustering.evaluate(ax=ax, ax_props={"xlim": (-180, 180), "ylim": (-180, 180), "aspect": "equal"})
# Out:
# (<Figure size 600x370.828 with 1 Axes>,
#  <AxesSubplot:xlabel='$x$', ylabel='$y$'>)

# %% [markdown]
# ##### Hierarchical manual

# %%
r = 20
c = 30

h_clustering = cluster.prepare_clustering(data)
h_clustering._metric = _types.MetricExtEuclideanPeriodicReduced(
    np.array([360, 360], dtype=float)
)

h_clustering.fit(r, c, member_cutoff=20, v=False)
h_clustering.isolate()

# %%
for sub_clustering, (r, c) in [(h_clustering.children[1], (5.5, 30)), (h_clustering.children[2], (8.5, 30))]:
    sub_clustering.fit(r, c, member_cutoff=20, v=False)
    sub_clustering.isolate()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-309-c9fdb41d48d2> in <module>
#       1 for sub_clustering, (r, c) in [(h_clustering.children[1], (5.5, 30)), (h_clustering.children[2], (8.5, 30))]:
#       2     sub_clustering.fit(r, c, member_cutoff=20, v=False)
# ----> 3     sub_clustering.isolate()
#
# src/cnnclustering/cluster.pyx in cnnclustering.cluster.Clustering.isolate()
#
# TypeError: Expected list, got numpy.ndarray

# %%
fig, ax = plt.subplots(figsize=(2, 2/1.618))
h_clustering.pie(ax=ax)
# Out:
# 5002
# 5002
# (<Figure size 600x370.828 with 1 Axes>, <AxesSubplot:>)

# %%
fig, ax = plt.subplots(figsize=(2, 2))
h_clustering.tree(ax=ax)
fig.tight_layout()

# %%
h_clustering.children
# Out:
# defaultdict(<cyfunction Clustering.isolate.<locals>.<lambda> at 0x7fc5f8f84ba0>,
#             {1: Clustering(input_data=<cnnclustering._types.InputDataExtPointsMemoryview object at 0x7fc5f5cfd590>, neighbours_getter=<cnnclustering._types.NeighboursGetterExtBruteForce object at 0x7fc5fd79d990>, neighbours=<cnnclustering._types.NeighboursExtVector object at 0x7fc5f8318c30>, neighbour_neighbours=<cnnclustering._types.NeighboursExtVector object at 0x7fc5f8318b70>, metric=<cnnclustering._types.MetricExtEuclideanPeriodicReduced object at 0x7fc5fdb0cc60>, similarity_checker=<cnnclustering._types.SimilarityCheckerExtContains object at 0x7fc5f85da250>, queue=<cnnclustering._types.QueueExtFIFOQueue object at 0x7fc5f9410a40>, fitter=<cnnclustering._fit.FitterExtBFS object at 0x7fc5f85da150>, predictor=None),
#              2: Clustering(input_data=<cnnclustering._types.InputDataExtPointsMemoryview object at 0x7fc5f5cfd370>, neighbours_getter=<cnnclustering._types.NeighboursGetterExtBruteForce object at 0x7fc5fd79d990>, neighbours=<cnnclustering._types.NeighboursExtVector object at 0x7fc5f8318c30>, neighbour_neighbours=<cnnclustering._types.NeighboursExtVector object at 0x7fc5f8318b70>, metric=<cnnclustering._types.MetricExtEuclideanPeriodicReduced object at 0x7fc5fdb0cc60>, similarity_checker=<cnnclustering._types.SimilarityCheckerExtContains object at 0x7fc5f85da250>, queue=<cnnclustering._types.QueueExtFIFOQueue object at 0x7fc5f9410a40>, fitter=<cnnclustering._fit.FitterExtBFS object at 0x7fc5f85da150>, predictor=None),
#              0: Clustering(input_data=<cnnclustering._types.InputDataExtPointsMemoryview object at 0x7fc5f5cfd260>, neighbours_getter=<cnnclustering._types.NeighboursGetterExtBruteForce object at 0x7fc5fd79d990>, neighbours=<cnnclustering._types.NeighboursExtVector object at 0x7fc5f8318c30>, neighbour_neighbours=<cnnclustering._types.NeighboursExtVector object at 0x7fc5f8318b70>, metric=<cnnclustering._types.MetricExtEuclideanPeriodicReduced object at 0x7fc5fdb0cc60>, similarity_checker=<cnnclustering._types.SimilarityCheckerExtContains object at 0x7fc5f85da250>, queue=<cnnclustering._types.QueueExtFIFOQueue object at 0x7fc5f9410a40>, fitter=<cnnclustering._fit.FitterExtBFS object at 0x7fc5f85da150>, predictor=None),
#              3: Clustering(input_data=<cnnclustering._types.InputDataExtPointsMemoryview object at 0x7fc5f5cfd150>, neighbours_getter=<cnnclustering._types.NeighboursGetterExtBruteForce object at 0x7fc5fd79d990>, neighbours=<cnnclustering._types.NeighboursExtVector object at 0x7fc5f8318c30>, neighbour_neighbours=<cnnclustering._types.NeighboursExtVector object at 0x7fc5f8318b70>, metric=<cnnclustering._types.MetricExtEuclideanPeriodicReduced object at 0x7fc5fdb0cc60>, similarity_checker=<cnnclustering._types.SimilarityCheckerExtContains object at 0x7fc5f85da250>, queue=<cnnclustering._types.QueueExtFIFOQueue object at 0x7fc5f9410a40>, fitter=<cnnclustering._fit.FitterExtBFS object at 0x7fc5f85da150>, predictor=None)})

# %%
graph = h_clustering.to_nx_DiGraph()

# %%
graph.nodes
# Out:
# NodeView(('1', '1.1', '1.2', '1.0', '1.3'))

# %%
h_clustering.reel()

# %%
fig, ax = plt.subplots(figsize=(2, 2/1.618))
h_clustering.evaluate(ax=ax, ax_props={"xlim": (-180, 180), "ylim": (-180, 180), "aspect": "equal"})
# Out:
# (<Figure size 600x370.828 with 1 Axes>,
#  <AxesSubplot:xlabel='$x$', ylabel='$y$'>)

# %%
h_clustering._neighbours_getter.is_selfcounting
# Out:
# True

# %%
clustering._neighbours_getter.is_selfcounting
# Out:
# True
