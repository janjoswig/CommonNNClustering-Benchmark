# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Helper-function-definitions" data-toc-modified-id="Helper-function-definitions-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Helper function definitions</a></span><ul class="toc-item"><li><span><a href="#Plotting" data-toc-modified-id="Plotting-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Plotting</a></span></li><li><span><a href="#Organisation" data-toc-modified-id="Organisation-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Organisation</a></span></li></ul></li><li><span><a href="#No-structure" data-toc-modified-id="No-structure-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>No structure</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Checks</a></span></li><li><span><a href="#Scan" data-toc-modified-id="Scan-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Scan</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Plots</a></span><ul class="toc-item"><li><span><a href="#Time" data-toc-modified-id="Time-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Time</a></span><ul class="toc-item"><li><span><a href="#Trends" data-toc-modified-id="Trends-2.3.1.1"><span class="toc-item-num">2.3.1.1&nbsp;&nbsp;</span>Trends</a></span></li></ul></li><li><span><a href="#Noise-level" data-toc-modified-id="Noise-level-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Noise level</a></span></li><li><span><a href="#Largest-cluster" data-toc-modified-id="Largest-cluster-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Largest cluster</a></span></li><li><span><a href="#Number-of-clusters" data-toc-modified-id="Number-of-clusters-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Number of clusters</a></span></li></ul></li></ul></li><li><span><a href="#Blobs" data-toc-modified-id="Blobs-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Blobs</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Checks</a></span></li><li><span><a href="#Scan" data-toc-modified-id="Scan-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Scan</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Plots</a></span><ul class="toc-item"><li><span><a href="#Time" data-toc-modified-id="Time-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Time</a></span></li><li><span><a href="#Noise-level" data-toc-modified-id="Noise-level-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Noise level</a></span></li><li><span><a href="#Largest-cluster" data-toc-modified-id="Largest-cluster-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Largest cluster</a></span></li><li><span><a href="#Number-of-clusters" data-toc-modified-id="Number-of-clusters-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>Number of clusters</a></span></li></ul></li></ul></li><li><span><a href="#Moons" data-toc-modified-id="Moons-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Moons</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Checks</a></span></li><li><span><a href="#Scan" data-toc-modified-id="Scan-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Scan</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Plots</a></span><ul class="toc-item"><li><span><a href="#Time" data-toc-modified-id="Time-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Time</a></span></li><li><span><a href="#Noise-level" data-toc-modified-id="Noise-level-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Noise level</a></span></li><li><span><a href="#Largest-cluster" data-toc-modified-id="Largest-cluster-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Largest cluster</a></span></li><li><span><a href="#Number-of-clusters" data-toc-modified-id="Number-of-clusters-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Number of clusters</a></span></li></ul></li></ul></li><li><span><a href="#Circles" data-toc-modified-id="Circles-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Circles</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Checks</a></span></li><li><span><a href="#Scan" data-toc-modified-id="Scan-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Scan</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Plots</a></span><ul class="toc-item"><li><span><a href="#Time" data-toc-modified-id="Time-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Time</a></span></li><li><span><a href="#Noise-level" data-toc-modified-id="Noise-level-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Noise level</a></span></li><li><span><a href="#Largest-cluster" data-toc-modified-id="Largest-cluster-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>Largest cluster</a></span></li><li><span><a href="#Number-of-clusters" data-toc-modified-id="Number-of-clusters-5.3.4"><span class="toc-item-num">5.3.4&nbsp;&nbsp;</span>Number of clusters</a></span></li></ul></li></ul></li><li><span><a href="#Varied" data-toc-modified-id="Varied-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Varied</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Checks</a></span></li><li><span><a href="#Scan" data-toc-modified-id="Scan-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Scan</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Plots</a></span><ul class="toc-item"><li><span><a href="#Time" data-toc-modified-id="Time-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Time</a></span></li><li><span><a href="#Noise-level" data-toc-modified-id="Noise-level-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>Noise level</a></span></li><li><span><a href="#Largest-cluster" data-toc-modified-id="Largest-cluster-6.3.3"><span class="toc-item-num">6.3.3&nbsp;&nbsp;</span>Largest cluster</a></span></li><li><span><a href="#Number-of-clusters" data-toc-modified-id="Number-of-clusters-6.3.4"><span class="toc-item-num">6.3.4&nbsp;&nbsp;</span>Number of clusters</a></span></li><li><span><a href="#Evaluation" data-toc-modified-id="Evaluation-6.3.5"><span class="toc-item-num">6.3.5&nbsp;&nbsp;</span>Evaluation</a></span></li></ul></li></ul></li><li><span><a href="#Aniso" data-toc-modified-id="Aniso-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Aniso</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Checks</a></span></li><li><span><a href="#Scan" data-toc-modified-id="Scan-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Scan</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Plots</a></span><ul class="toc-item"><li><span><a href="#Time" data-toc-modified-id="Time-7.3.1"><span class="toc-item-num">7.3.1&nbsp;&nbsp;</span>Time</a></span></li><li><span><a href="#Noise-level" data-toc-modified-id="Noise-level-7.3.2"><span class="toc-item-num">7.3.2&nbsp;&nbsp;</span>Noise level</a></span></li><li><span><a href="#Largest-cluster" data-toc-modified-id="Largest-cluster-7.3.3"><span class="toc-item-num">7.3.3&nbsp;&nbsp;</span>Largest cluster</a></span></li><li><span><a href="#Number-of-clusters" data-toc-modified-id="Number-of-clusters-7.3.4"><span class="toc-item-num">7.3.4&nbsp;&nbsp;</span>Number of clusters</a></span></li><li><span><a href="#Evaluation" data-toc-modified-id="Evaluation-7.3.5"><span class="toc-item-num">7.3.5&nbsp;&nbsp;</span>Evaluation</a></span></li></ul></li></ul></li><li><span><a href="#Backbone-dihedrals" data-toc-modified-id="Backbone-dihedrals-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Backbone dihedrals</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Checks</a></span></li><li><span><a href="#Scan" data-toc-modified-id="Scan-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Scan</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Plots</a></span><ul class="toc-item"><li><span><a href="#Time" data-toc-modified-id="Time-8.3.1"><span class="toc-item-num">8.3.1&nbsp;&nbsp;</span>Time</a></span></li><li><span><a href="#Noise-level" data-toc-modified-id="Noise-level-8.3.2"><span class="toc-item-num">8.3.2&nbsp;&nbsp;</span>Noise level</a></span></li><li><span><a href="#Largest-cluster" data-toc-modified-id="Largest-cluster-8.3.3"><span class="toc-item-num">8.3.3&nbsp;&nbsp;</span>Largest cluster</a></span></li><li><span><a href="#Number-of-clusters" data-toc-modified-id="Number-of-clusters-8.3.4"><span class="toc-item-num">8.3.4&nbsp;&nbsp;</span>Number of clusters</a></span></li><li><span><a href="#Evaluation" data-toc-modified-id="Evaluation-8.3.5"><span class="toc-item-num">8.3.5&nbsp;&nbsp;</span>Evaluation</a></span><ul class="toc-item"><li><span><a href="#Hierarchical-manual" data-toc-modified-id="Hierarchical-manual-8.3.5.1"><span class="toc-item-num">8.3.5.1&nbsp;&nbsp;</span>Hierarchical manual</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Peptide-(TICA)" data-toc-modified-id="Peptide-(TICA)-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Peptide (TICA)</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Checks</a></span></li><li><span><a href="#Scan" data-toc-modified-id="Scan-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Scan</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Plots</a></span><ul class="toc-item"><li><span><a href="#Time" data-toc-modified-id="Time-9.3.1"><span class="toc-item-num">9.3.1&nbsp;&nbsp;</span>Time</a></span></li><li><span><a href="#Noise-level" data-toc-modified-id="Noise-level-9.3.2"><span class="toc-item-num">9.3.2&nbsp;&nbsp;</span>Noise level</a></span></li><li><span><a href="#Largest-cluster" data-toc-modified-id="Largest-cluster-9.3.3"><span class="toc-item-num">9.3.3&nbsp;&nbsp;</span>Largest cluster</a></span></li><li><span><a href="#Number-of-clusters" data-toc-modified-id="Number-of-clusters-9.3.4"><span class="toc-item-num">9.3.4&nbsp;&nbsp;</span>Number of clusters</a></span></li><li><span><a href="#Evaluation" data-toc-modified-id="Evaluation-9.3.5"><span class="toc-item-num">9.3.5&nbsp;&nbsp;</span>Evaluation</a></span></li><li><span><a href="#Hierarchical-semi-automatic" data-toc-modified-id="Hierarchical-semi-automatic-9.3.6"><span class="toc-item-num">9.3.6&nbsp;&nbsp;</span>Hierarchical semi-automatic</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Cluster parameter scans

# %% [markdown]
# Remember to compile `cnnclustering` with `TRACE_CYTHON=0` if timings should be measured.

# %%
from collections import defaultdict
import itertools
import json

import cnnclustering
from cnnclustering import cluster, plot
from cnnclustering import _fit, _primitive_types, _types
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets
from sklearn.metrics import pairwise_distances
from sklearn.neighbors import KDTree
from sklearn.preprocessing import StandardScaler
from tqdm.notebook import tqdm

import helper

# %%
import importlib
importlib.reload(helper)
# Out:
# <module 'helper' from '/home/janjoswig/repo/CommonNNClustering/docsrc/benchmark/helper.py'>

# %%
mpl.rcParams["figure.dpi"] = 300
mpl.rcParams["font.size"] = 6
mpl.rcParams["figure.figsize"] = (2, 2/1.618)

# %%
print(f"{'Python':>20} :  ", *sys.version.splitlines())
# Out:
#               Python :   3.8.8 (default, Mar 11 2021, 08:58:19)  [GCC 8.3.0]

# %%
print(f"cnnclustering :  ", cnnclustering.__version__)
# Out:
# cnnclustering :   0.4.1

# %% [markdown]
# ## Helper function definitions

# %%
neighbours_sorted_recipe = {
    "input_data": _types.InputDataExtNeighboursMemoryview,
    "neighbours_getter": _types.NeighboursGetterExtLookup,
    "neighbours": (_types.NeighboursExtVector, (5000,), {}),
    "neighbour_neighbours": (_types.NeighboursExtVector, (5000,), {}),
    "metric": _types.MetricExtDummy,
    "similarity_checker": _types.SimilarityCheckerExtScreensorted,
    "queue": _types.QueueExtFIFOQueue,
    "fitter": _fit.FitterExtBFS,
}

# %%
neighbours_sorted_alternative_recipe = {
    "input_data": _types.InputDataExtPointsMemoryview,
    "neighbours_getter": (_types.NeighboursGetterSklearnKDTree, (), {"is_sorted": True}),
    "neighbours": (_types.NeighboursExtVector, (5000,), {}),
    "neighbour_neighbours": (_types.NeighboursExtVector, (5000,), {}),
    "metric": _types.MetricExtDummy,
    "similarity_checker": _types.SimilarityCheckerExtScreensorted,
    "queue": _types.QueueExtFIFOQueue,
    "fitter": _fit.FitterBFS,
}

# %%
if "CLUSTERING_MAP" not in dir():
    CLUSTERING_MAP = {}

# %%
overwrite = False
record_file = pathlib.Path("records/records.json")
if record_file.is_file() and not overwrite:
    raise RuntimeError(f"File exists: str(record_file)")

with open(record_file, "w") as fp:
    json.dump({k: v.summary._list for k, v in CLUSTERING_MAP.items()}, fp, cls=helper.RecordEncoder, indent=4)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-2d943096d177> in <module>
#       2 record_file = pathlib.Path("records/records.json")
#       3 if record_file.is_file() and not overwrite:
# ----> 4     raise RuntimeError(f"File exists: str(record_file)")
#       5
#       6 with open(record_file, "w") as fp:
#
# RuntimeError: File exists: str(record_file)

# %%
with open("records/records.json", "r") as fp:
    RECORD_MAP = json.load(fp, object_hook=helper.as_Record)

# %%
overwrite = False
record_file = pathlib.Path("records/records.json")
if record_file.is_file() and not overwrite:
    raise RuntimeError(f"File exists: str(record_file)")

with open(record_file, "w") as fp:
    json.dump(RECORD_MAP, fp, cls=helper.RecordEncoder, indent=4)

# %%
for scan_name, cl in CLUSTERING_MAP.items():
    print(scan_name, cl.summary[-1])

# %% [markdown]
# ### Plotting

# %%
def calc_histogram(x, hist_props=None, save=False, base_name=None):
    
    hist_props_defaults = {
        "bins": 100,
        "density": True,
        }
    
    if hist_props is not None:
        hist_props_defaults.update(hist_props)
    
    histogram, bins = np.histogram(
        x,
        **hist_props_defaults
        )
    binmids = 0.5 * (bins[:-1] + bins[1:])

    if save:
        if base_name is None:
            raise ValueError("If 'save=True', need to provide 'basename'")
     
        np.save(f"{base_name}_hist.npy", histogram)
        np.save(f"{base_name}_binmids.npy", binmids)
    
    return histogram, binmids

# %%
def calc_n_neighbours_per_radius(distances, save=False, base_name=None):
    min_n = []
    max_n = []
    mean_n = []

    upper_dist_bound = np.ceil(distances.max())
    r_array = np.linspace(0, upper_dist_bound, int(f"{bound:1.0e}".split("e")[0]) * 10 + 1)

    for r in r_array:
        adjecancy = np.where(distances < r, 1, 0)
        n_neighbours = np.sum(adjecancy, axis=0) - 1
        min_n.append(n_neighbours.min())
        max_n.append(n_neighbours.max())
        mean_n.append(n_neighbours.mean())
        
    min_n = np.asarray(min_n)
    max_n = np.asarray(max_n)
    mean_n = np.asarray(mean_n)

    if save:
        if base_name is None:
            raise ValueError("If 'save=True', need to provide 'basename'")
     
        np.save(f"{base_name}_r_array.npy", r_array)
        np.save(f"{base_name}_min_n.npy", min_n)
        np.save(f"{base_name}_max_n.npy", max_n)
        np.save(f"{base_name}_mean_n.npy", mean_n)  
        
    return r_array, min_n, max_n, mean_n

# %%
def plot_n_neighbours_per_radius(r_array, min_n, max_n, mean_n, dist_hist_cutoff, n_points):

    fig, (full_ax, zoom_ax) = plt.subplots(
        1, 2,
        figsize=(
            mpl.rcParams["figure.figsize"][0] * 1.5,
            mpl.rcParams["figure.figsize"][1]
        )
    )

    full_ax.plot(r_array, min_n)
    full_ax.plot(r_array, max_n)
    full_ax.plot(r_array, mean_n)

    full_ax.axvline(dist_hist_cutoff, color="k", linestyle="--", linewidth=0.5)
    intersection_index = np.argwhere(r_array < dist_hist_cutoff)[-1][0]
    intersection_ticks = []
    for intersection_list in [min_n, max_n, mean_n]:
        intersection_y = (
            (intersection_list[intersection_index] + intersection_list[intersection_index + 1])
            / 2
            )
        intersection_ticks.append(intersection_y)
        full_ax.hlines(
            y=intersection_y,
            xmin=0, xmax=dist_hist_cutoff,
            color="k", linestyle="--", linewidth=0.5,
            transform=full_ax.transData,
            zorder=3
        )
    full_ax.set_yticks((0, n_points))
    full_ax.set_yticks(intersection_ticks, minor=True)
    full_ax.set_yticklabels(
        [int(t) for t in intersection_ticks],
        minor=True,
        fontsize="x-small"
        )
    full_ax.set_xlim(0, r_array[-1])
    full_ax.set_xlabel("$r$")
    full_ax.set_ylabel("# neighbours")
    
    zoom_ax.plot(r_array, min_n)
    zoom_ax.plot(r_array, max_n)
    zoom_ax.plot(r_array, mean_n)
    zoom_ax.set_xlim(0, dist_hist_cutoff)
    zoom_ax.set_ylim(0, np.ceil(intersection_ticks[2]))
    zoom_ax.set_xlabel("$r$")
    zoom_ax.legend(["min", "max", "mean"])
    plt.tight_layout(pad=0.1, w_pad=1)

# %% [markdown]
# ### Organisation

# %% [markdown]
# Ignore/modify these if needed.

# %%
# Find data sets in ...
data_dir = pathlib.Path(os.path.expandvars("$WD/CommonNN"))

# %%
# Save observations to ...
figsrc_dir = pathlib.Path(data_dir / "Manuscript/figsrc/Scans")

# %% [markdown]
# ## No structure

# %%
scan_name = "no_structure"

# %%
data = helper.gen_no_structure_points((5000, 2))
distances = pairwise_distances(data)
n_points = data.shape[0]

fig, ax = plt.subplots(figsize=(1, 1))
ax.scatter(
    *data.T,
    s=0.5,
)

# %% [markdown]
# ### Checks

# %%
fig, ax = plt.subplots()
_ = plot.plot_histogram(ax, distances.flatten(), maxima=True, maxima_props={"order": 5})

# %%
h, binmids = calc_histogram(distances.flatten(), save=True, base_name=figsrc_dir / f"{scan_name}_dist")

# %%
print("Min: ", distances[distances > 0].min())
print("Max: ", distances.max())
# Out:
# Min:  0.00027307491487952
# Max:  4.842668307314774

# %%
r_array, min_n, max_n, mean_n = calc_n_neighbours_per_radius(
    distances, save=True, base_name=figsrc_dir / f"{scan_name}"
    )

# %%
plot_n_neighbours_per_radius(
    r_array, min_n, max_n, mean_n,
    1.67, n_points
)

# %% [markdown]
# ### Scan

# %%
scan_name = "no_structure"
clustering = CLUSTERING_MAP[scan_name] = cluster.prepare_clustering(data)

# %%
for record in RECORD_MAP[scan_name]:
    clustering.summary.append(record)

# %%
for r in tqdm(np.arange(0.01, 1.01, 0.01)):
    neighbours = helper.compute_neighbours(data, r, sort=True)
    neighbours_clustering = cluster.prepare_clustering(
        neighbours,
        preparation_hook=cluster.prepare_neighbourhoods,
        **neighbours_sorted_recipe
    )

    for c in range(151):
        neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
        clustering.summary.append(neighbours_clustering.summary[-1])
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
clustering.summary.to_DataFrame()
# Out:
#        n_points  radius_cutoff  cnn_cutoff  member_cutoff  max_clusters  \
# 0          5000           0.01           0             20          <NA>
# 1          5000           0.01           1             20          <NA>
# 2          5000           0.01           2             20          <NA>
# 3          5000           0.01           3             20          <NA>
# 4          5000           0.01           4             20          <NA>
# ...         ...            ...         ...            ...           ...
# 15095      5000           1.00         146             20          <NA>
# 15096      5000           1.00         147             20          <NA>
# 15097      5000           1.00         148             20          <NA>
# 15098      5000           1.00         149             20          <NA>
# 15099      5000           1.00         150             20          <NA>
#
#        n_clusters  ratio_largest  ratio_noise  execution_time
# 0               0            0.0          1.0        0.000189
# 1               0            0.0          1.0        0.000126
# 2               0            0.0          1.0        0.000124
# 3               0            0.0          1.0        0.000122
# 4               0            0.0          1.0        0.000124
# ...           ...            ...          ...             ...
# 15095           1            1.0          0.0        0.038833
# 15096           1            1.0          0.0        0.039439
# 15097           1            1.0          0.0        0.038678
# 15098           1            1.0          0.0        0.039222
# 15099           1            1.0          0.0        0.039001
#
# [15100 rows x 9 columns]

# %% [markdown]
# ### Plots

# %%
scan_name = "no_structure"
clustering = CLUSTERING_MAP[scan_name]

# %% [markdown]
# #### Time

# %%
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="execution_time",
    contour_props={
        "levels": 50,
        # "locator": mpl.ticker.LogLocator()
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax)
colorbar.set_label("time / s")

ax.set_xlim(0.01, 1)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# ##### Trends
#
# Clustering for fixed CommonNN cutoff $c$ is fast if the ...
#
#   - ... radius cutoff is small: majority of points has not enough neighbours and is immediately declared noise (no checking of the density criterion.
#   - ... radius cutoff is large: majority of points has a large share of the total number of points as neighbours and ends up in the same cluster (low number of re-checks)
#
# Generally clustering takes more time if the ...
#
#   - ... radius cutoff is large: more neighbours have to be retrieved; more neighbours have to be checked (assuming CommonNN cutoff is comparably low)
#   - ... CommoNN cutoff is large: checking takes more time; larger number of re-checks (assuming CommonNN cutoff is comparably low)

# %% [markdown]
# #### Noise level

# %%
# Noise level
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax, quantity="ratio_noise",
    contour_props={
        "levels": 100,
        "vmin": 0,
        "vmax": 1,
    },
    # convert=lambda x: x * 100
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("noise / %")

ax.set_xlim(0.01, 1)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Largest cluster

# %%
# Largest cluster
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_largest",
    contour_props={
        "levels": 100,
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("largest / %")

ax.set_xlim(0.01, 1)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Number of clusters

# %%
# Number of clusters
show_n = 10

fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="n_clusters",
    contour_props={
        "levels": np.arange(-0.5, show_n + 1.5, 1),
        "vmin": 0,
        "vmax": show_n,
        "extend": "max"
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=range(0, show_n + 1, 2))
colorbar.set_label("# clusters")

ax.set_xlim(0.01, 1)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# ## Blobs

# %%
scan_name = "blobs"

# %%
# The test data
data = helper.gen_blobs_points((5000, 2))
distances = pairwise_distances(data)
n_points = data.shape[0]

fig, ax = plt.subplots(figsize=(1, 1))
ax.scatter(
    *data.T,
    s=0.5,    
)

# %% [markdown]
# ### Checks

# %%
fig, ax = plt.subplots()
_ = plot.plot_histogram(ax, distances.flatten(), maxima=True, maxima_props={"order": 5})

# %%
h, binmids = calc_histogram(distances.flatten(), save=True, base_name=figsrc_dir / f"{scan_name}_dist")

# %%
print("Min: ", distances[distances > 0].min())
print("Max: ", distances.max())
# Out:
# Min:  4.422092256111229e-05
# Max:  4.097490617525474

# %%
r_array, min_n, max_n, mean_n = calc_n_neighbours_per_radius(
    distances, save=True, base_name=figsrc_dir / f"{scan_name}"
    )

# %%
plot_n_neighbours_per_radius(
    r_array, min_n, max_n, mean_n,
    0.18, n_points
)

# %% [markdown]
# ### Scan

# %%
scan_name = "blobs"
clustering = CLUSTERING_MAP[scan_name] = cluster.prepare_clustering(data)

# %%
for r in tqdm(np.arange(0.01, 0.61, 0.01)):
    neighbours = helper.compute_neighbours(data, r, sort=True)
    neighbours_clustering = cluster.prepare_clustering(
        neighbours,
        preparation_hook=cluster.prepare_neighbourhoods,
        **neighbours_sorted_recipe
    )

    for c in range(151):
        neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
        clustering.summary.append(neighbours_clustering.summary[-1])
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]

# %% [markdown]
# ### Plots

# %%
scan_name = "blobs"
clustering = CLUSTERING_MAP[scan_name]

# %% [markdown]
# #### Time

# %%
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="execution_time",
    contour_props={
        "levels": 50,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax)
colorbar.set_label("time / s")

ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Noise level

# %%
# Noise level
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_noise",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("noise / %")

ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Largest cluster

# %%
# Largest cluster
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_largest",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("largest / %")

ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Number of clusters

# %%
# Number of clusters
show_n = 10

fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="n_clusters",
    contour_props={
        "levels": np.arange(-0.5, show_n + 1.5, 1),
        "vmin": 0,
        "vmax": show_n,
        "extend": "max"
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=range(0, show_n + 1, 2))
colorbar.set_label("# clusters")

ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# ## Moons

# %%
scan_name = "moons"

# %%
# The test data
data = helper.gen_moons_points(
    (5000, 2),
    noise=.05
)
distances = pairwise_distances(data)
n_points = data.shape[0]

fig, ax = plt.subplots(figsize=(1, 1))
ax.scatter(
    *data.T,
    s=0.5,
)

# %% [markdown]
# ### Checks

# %%
fig, ax = plt.subplots()
_ = plot.plot_histogram(ax, distances.flatten(), maxima=True, maxima_props={"order": 5})

# %%
h, binmids = calc_histogram(distances.flatten(), save=True, base_name=figsrc_dir / f"{scan_name}_dist")

# %%
print("Min: ", distances[distances > 0].min())
print("Max: ", distances.max())
# Out:
# Min:  9.927475001661245e-05
# Max:  3.892931346774215

# %%
r_array, min_n, max_n, mean_n = calc_n_neighbours_per_radius(
    distances, save=True, base_name=figsrc_dir / f"{scan_name}"
    )

# %%
plot_n_neighbours_per_radius(
    r_array, min_n, max_n, mean_n,
    0.21, n_points
)

# %% [markdown]
# ### Scan

# %%
scan_name = "moons"
clustering = CLUSTERING_MAP[scan_name] = cluster.prepare_clustering(data)

# %%
for r in tqdm(np.arange(0.01, 0.61, 0.01)):
    neighbours = helper.compute_neighbours(data, r, sort=True)
    neighbours_clustering = cluster.prepare_clustering(
        neighbours,
        preparation_hook=cluster.prepare_neighbourhoods,
        **neighbours_sorted_recipe
    )

    for c in range(151):
        neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
        clustering.summary.append(neighbours_clustering.summary[-1])
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]

# %% [markdown]
# ### Plots

# %%
scan_name = "moons"
clustering = CLUSTERING_MAP[scan_name]

# %% [markdown]
# #### Time

# %%
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="execution_time",
    contour_props={
        "levels": 50,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax)
colorbar.set_label("time / s")

ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Noise level

# %%
# Noise level
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_noise",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("noise / %")

ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Largest cluster

# %%
# Largest cluster
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_largest",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("largest / %")

ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Number of clusters

# %%
# Number of clusters
show_n = 10

fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="n_clusters",
    contour_props={
        "levels": np.arange(-0.5, show_n + 1.5, 1),
        "vmin": 0,
        "vmax": show_n,
        "extend": "max"
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=range(0, show_n + 1, 2))
colorbar.set_label("# clusters")

ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# ## Circles

# %%
scan_name = "circles"

# %%
# The test data
data = helper.gen_circles_points(
    (5000, 2),
    factor=.5,
    noise=.05
)
n_points = data.shape[0]
distances = pairwise_distances(data)

fig, ax = plt.subplots(figsize=(1, 1))
ax.scatter(
    *data.T,
    s=0.5,
)

# %% [markdown]
# ### Checks

# %%
fig, ax = plt.subplots()
_ = plot.plot_histogram(ax, distances.flatten(), maxima=True, maxima_props={"order": 5})

# %%
h, binmids = calc_histogram(distances.flatten(), save=True, base_name=figsrc_dir / f"{scan_name}_dist")

# %%
print("Min: ", distances[distances > 0].min())
print("Max: ", distances.max())
# Out:
# Min:  0.0001264168234122532
# Max:  4.199475414902217

# %%
r_array, min_n, max_n, mean_n = calc_n_neighbours_per_radius(
    distances, save=True, base_name=figsrc_dir / f"{scan_name}"
    )

# %%
plot_n_neighbours_per_radius(
    r_array, min_n, max_n, mean_n,
    0.23, n_points
)

# %% [markdown]
# ### Scan

# %%
scan_name = "circles"
clustering = CLUSTERING_MAP[scan_name] = cluster.prepare_clustering(data)

# %%
for r in tqdm(np.arange(0.01, 0.61, 0.01)):
    neighbours = helper.compute_neighbours(data, r, sort=True)
    neighbours_clustering = cluster.prepare_clustering(
        neighbours,
        preparation_hook=cluster.prepare_neighbourhoods,
        **neighbours_sorted_recipe
    )

    for c in range(151):
        neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
        clustering.summary.append(neighbours_clustering.summary[-1])
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]

# %% [markdown]
# ### Plots

# %%
scan_name = "circles"
clustering = CLUSTERING_MAP[scan_name]

# %% [markdown]
# #### Time

# %%
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="execution_time",
    contour_props={
        "levels": 50,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax)
colorbar.set_label("time / s")

ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Noise level

# %%
# Noise level
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_noise",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("noise / %")

ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Largest cluster

# %%
# Largest cluster
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_largest",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("largest / %")

ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Number of clusters

# %%
# Number of clusters
show_n = 10

fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="n_clusters",
    contour_props={
        "levels": np.arange(-0.5, show_n + 1.5, 1),
        "vmin": 0,
        "vmax": show_n,
        "extend": "max"
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=range(0, show_n + 1, 2))
colorbar.set_label("# clusters")

ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# ## Varied

# %%
scan_name = "varied"

# %%
# The test data
data = helper.gen_blobs_points(
    (5000, 2),
    random_state=170,
    cluster_std=[1.0, 2.5, 0.5],
)
n_points = data.shape[0]
distances = pairwise_distances(data)

fig, ax = plt.subplots(figsize=(1, 1))
ax.scatter(
    *data.T,
    s=0.5,
)

# %% [markdown]
# ### Checks

# %%
fig, ax = plt.subplots()
_ = plot.plot_histogram(ax, distances.flatten(), maxima=True, maxima_props={"order": 5})

# %%
h, binmids = calc_histogram(distances.flatten(), save=True, base_name=figsrc_dir / f"{scan_name}_dist")

# %%
print("Min: ", distances[distances > 0].min())
print("Max: ", distances.max())
# Out:
# Min:  0.00021837824482724168
# Max:  5.457257351668825

# %%
r_array, min_n, max_n, mean_n = calc_n_neighbours_per_radius(
    distances, save=True, base_name=figsrc_dir / f"{scan_name}"
    )

# %%
plot_n_neighbours_per_radius(
    r_array, min_n, max_n, mean_n,
    0.19, n_points
)

# %% [markdown]
# ### Scan

# %%
scan_name = "varied"
clustering = CLUSTERING_MAP[scan_name] = cluster.prepare_clustering(data)

# %%
for r in tqdm(np.arange(0.01, 0.51, 0.01)):
    neighbours = helper.compute_neighbours(data, r, sort=True)
    neighbours_clustering = cluster.prepare_clustering(
        neighbours,
        preparation_hook=cluster.prepare_neighbourhoods,
        **neighbours_sorted_recipe
    )

    for c in range(151):
        neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
        clustering.summary.append(neighbours_clustering.summary[-1])
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# ### Plots

# %%
scan_name = "varied"
clustering = CLUSTERING_MAP[scan_name]

# %%
clustering.summary.to_DataFrame()
# Out:
#       n_points  radius_cutoff  cnn_cutoff  member_cutoff  max_clusters  \
# 0         5000           0.01           0             20          <NA>
# 1         5000           0.01           1             20          <NA>
# 2         5000           0.01           2             20          <NA>
# 3         5000           0.01           3             20          <NA>
# 4         5000           0.01           4             20          <NA>
# ...        ...            ...         ...            ...           ...
# 7545      5000           0.50         146             20          <NA>
# 7546      5000           0.50         147             20          <NA>
# 7547      5000           0.50         148             20          <NA>
# 7548      5000           0.50         149             20          <NA>
# 7549      5000           0.50         150             20          <NA>
#
#       n_clusters  ratio_largest  ratio_noise  execution_time
# 0              5         0.0818       0.8856        0.001223
# 1              6         0.0198       0.9528        0.001058
# 2              2         0.0174       0.9784        0.000993
# 3              1         0.0108       0.9892        0.000940
# 4              1         0.0086       0.9914        0.000867
# ...          ...            ...          ...             ...
# 7545           1         0.9252       0.0748        0.555526
# 7546           1         0.9252       0.0748        0.568364
# 7547           1         0.9242       0.0758        0.595478
# 7548           1         0.9238       0.0762        0.584090
# 7549           1         0.9228       0.0772        0.578298
#
# [7550 rows x 9 columns]

# %% [markdown]
# #### Time

# %%
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="execution_time",
    contour_props={
        "levels": 50,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax)
colorbar.set_label("time / s")

ax.set_xlim(0.01, 0.5)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Noise level

# %%
# Noise level
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_noise",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("noise / %")
ax.set_xlim(0.01, 0.5)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Largest cluster

# %%
# Largest cluster
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_largest",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("largest / %")
ax.set_xlim(0.01, 0.5)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Number of clusters

# %%
# Number of clusters
show_n = 10

fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="n_clusters",
    contour_props={
        "levels": np.arange(-0.5, show_n + 1.5, 1),
        "vmin": 0,
        "vmax": show_n,
        "extend": "max"
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=range(0, show_n + 1, 2))
colorbar.set_label("# clusters")
ax.set_xlim(0.01, 0.5)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Evaluation

# %%
r = 0.2
c = 50

neighbours = helper.compute_neighbours(data, r, sort=True)
neighbours_clustering = cluster.prepare_clustering(
    neighbours,
    preparation_hook=cluster.prepare_neighbourhoods,
    **neighbours_sorted_recipe
)

neighbours_clustering.fit(0., c, member_cutoff=20, v=False)
clustering._labels = neighbours_clustering._labels

# %%
fig, ax = plt.subplots()
clustering.evaluate(ax=ax)
# Out:
# (<Figure size 600x370.828 with 1 Axes>,
#  <AxesSubplot:xlabel='$x$', ylabel='$y$'>)

# %% [markdown]
# ## Aniso

# %%
scan_name = "aniso"

# %%
# The test data
data = helper.gen_blobs_points(
    (5000, 2),
    random_state=170,
    
)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
data = np.dot(data, transformation)
n_points = data.shape[0]

distances = pairwise_distances(data)

fig, ax = plt.subplots(figsize=(1, 1))
ax.scatter(
    *data.T,
    s=0.5,
)

# %% [markdown]
# ### Checks

# %%
fig, ax = plt.subplots()
_ = plot.plot_histogram(ax, distances.flatten(), maxima=True, maxima_props={"order": 5})

# %%
h, binmids = calc_histogram(distances.flatten(), save=True, base_name=figsrc_dir / f"{scan_name}_dist")

# %%
print("Min: ", distances[distances > 0].min())
print("Max: ", distances.max())
# Out:
# Min:  0.0001934117086504001
# Max:  3.6222164035708793

# %%
r_array, min_n, max_n, mean_n = calc_n_neighbours_per_radius(
    distances, save=True, base_name=figsrc_dir / f"{scan_name}"
    )

# %%
plot_n_neighbours_per_radius(
    r_array, min_n, max_n, mean_n,
    0.13, n_points
)

# %% [markdown]
# ### Scan

# %%
scan_name = "aniso"
clustering = CLUSTERING_MAP[scan_name] = cluster.prepare_clustering(data)

# %%
for r in tqdm(np.arange(0.01, 0.61, 0.01)):
    neighbours = helper.compute_neighbours(data, r, sort=True)
    neighbours_clustering = cluster.prepare_clustering(
        neighbours,
        preparation_hook=cluster.prepare_neighbourhoods,
        **neighbours_sorted_recipe
    )

    for c in range(151):
        neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
        clustering.summary.append(neighbours_clustering.summary[-1])
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]

# %% [markdown]
# ### Plots

# %%
scan_name = "aniso"
clustering = CLUSTERING_MAP[scan_name]

# %% [markdown]
# #### Time

# %%
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="execution_time",
    contour_props={
        "levels": 50,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax)
colorbar.set_label("time / s")

ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Noise level

# %%
# Noise level
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_noise",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("noise / %")
ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %%
# Noise level
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_noise",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("noise / %")
ax.set_xlim(0.01, 0.13)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Largest cluster

# %%
# Largest cluster
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_largest",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("largest / %")
ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Number of clusters

# %%
# Number of clusters
show_n = 10

fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="n_clusters",
    contour_props={
        "levels": np.arange(-0.5, show_n + 1.5, 1),
        "vmin": 0,
        "vmax": show_n,
        "extend": "max"
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=range(0, show_n + 1, 2))
colorbar.set_label("# clusters")
ax.set_xlim(0.01, 0.6)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Evaluation

# %%
r = 0.13
c = 50

neighbours = helper.compute_neighbours(data, r, sort=True)
neighbours_clustering = cluster.prepare_clustering(
    neighbours,
    preparation_hook=cluster.prepare_neighbourhoods,
    **neighbours_sorted_recipe
)

neighbours_clustering.fit(0., c, member_cutoff=20, v=False)
clustering._labels = neighbours_clustering._labels

# %%
fig, ax = plt.subplots(figsize=(2, 2/1.618))
clustering.evaluate(ax=ax)
# Out:
# (<Figure size 1800x1200 with 1 Axes>, <AxesSubplot:xlabel='$x$', ylabel='$y$'>)

# %% [markdown]
# ## Backbone dihedrals

# %%
scan_name = "backbone"

# %%
# The test data
data_path = pathlib.Path(
    os.path.expandvars("$HOME/repo/CommonNNClustering/test/integration/test_procedures/backbone_dihedrals.npy")
    )
data = np.load(data_path)
n_points = data.shape[0]
        
fig, ax = plt.subplots(figsize=(1, 1))
ax.scatter(
    *data.T,
    s=0.5,
)

# %%
data_alt = _types.InputDataExtPointsMemoryview(data)
metric = _types.MetricExtEuclideanPeriodicReduced(np.array([360, 360], dtype=float))

distances = np.zeros((n_points, n_points))
for i in range(n_points):
    for j in range(i + 1, n_points):
        distances[i, j] = np.sqrt(metric.calc_distance(i, j, data_alt))
        
tril = np.tril_indices_from(distances)
distances[tril] = distances.T[tril]

# %% [markdown]
# ### Checks

# %%
fig, ax = plt.subplots()
_ = plot.plot_histogram(ax, distances.flatten(), maxima=True, maxima_props={"order": 5})

# %%
h, binmids = calc_histogram(distances.flatten(), save=True, base_name=figsrc_dir / f"{scan_name}_dist")

# %%
print("Min: ", distances[distances > 0].min())
print("Max: ", distances.max())
# Out:
# Min:  0.006020797289395393
# Max:  254.29970200612834

# %%
r_array, min_n, max_n, mean_n = calc_n_neighbours_per_radius(
    distances, save=True, base_name=figsrc_dir / f"{scan_name}"
    )

# %%
plot_n_neighbours_per_radius(
    r_array, min_n, max_n, mean_n,
    24.16, n_points
)

# %% [markdown]
# ### Scan

# %%
scan_name = "backbone"
clustering = CLUSTERING_MAP[scan_name] = cluster.prepare_clustering(data)

# %%
for record in RECORD_MAP[scan_name]:
    clustering.summary.append(record)

# %%
RECORD_MAP[scan_name] = clustering.summary._list

# %%
for r in tqdm(np.arange(1, 31, 1)):
    
    neighbours = [np.where(d < r)[0] for d in distances]
    for n in neighbours:
        n.sort()
        
    neighbours_clustering = cluster.prepare_clustering(
        neighbours,
        preparation_hook=cluster.prepare_neighbourhoods,
        **neighbours_sorted_recipe
    )

    for c in range(151):
        neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
        clustering.summary.append(neighbours_clustering.summary[-1])

# %% [markdown]
# ### Plots

# %%
scan_name = "backbone"
clustering = CLUSTERING_MAP[scan_name]

# %% [markdown]
# #### Time

# %%
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="execution_time",
    contour_props={
        "levels": 100,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax)
colorbar.set_label("time / s")

ax.set_xlim(1, 30)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Noise level

# %%
# Noise level
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_noise",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("noise / %")

ax.set_xlim(1, 30)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Largest cluster

# %%
# Largest cluster
fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_largest",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("largest / %")

ax.set_xlim(1, 30)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Number of clusters

# %%
# Number of clusters
show_n = 10

fig, ax = plt.subplots(figsize=(2, 2/1.618))
contour = clustering.summarize(
    ax=ax,
    quantity="n_clusters",
    contour_props={
        "levels": np.arange(-0.5, show_n + 1.5, 1),
        "vmin": 0,
        "vmax": show_n,
        "extend": "max"
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=range(0, show_n + 1, 2))
colorbar.set_label("# clusters")

ax.set_xlim(1, 30)
ax.set_ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# #### Evaluation

# %%
scan_name = "backbone"
clustering = cluster.prepare_clustering(data)

# %%
r = 20
c = 30

neighbours = [np.where(d < r)[0] for d in distances]
for n in neighbours:
    n.sort()
        
neighbours_clustering = cluster.prepare_clustering(
    neighbours,
    preparation_hook=cluster.prepare_neighbourhoods,
    **neighbours_sorted_recipe
)

neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
clustering._labels = neighbours_clustering._labels

# %%
fig, ax = plt.subplots()
clustering.evaluate(ax=ax, ax_props={"xlim": (-180, 180), "ylim": (-180, 180), "aspect": "equal"})
# Out:
# (<Figure size 600x370.828 with 1 Axes>,
#  <AxesSubplot:xlabel='$x$', ylabel='$y$'>)

# %%
np.save(figsrc_dir / scan_name / f"{scan_name}_labels_20_30.npy", clustering.labels.labels)

# %%
r = 8.1
c = 30

neighbours = [np.where(d < r)[0] for d in distances]
for n in neighbours:
    n.sort()
        
neighbours_clustering = cluster.prepare_clustering(
    neighbours,
    preparation_hook=cluster.prepare_neighbourhoods,
    **neighbours_sorted_recipe
)

neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
clustering._labels = neighbours_clustering._labels

# %%
fig, ax = plt.subplots()
clustering.evaluate(
    ax=ax,
    ax_props={
        "xlim": (-180, 180), "ylim": (-180, 180), "aspect": "equal"
    },
)
# Out:
# (<Figure size 600x370.828 with 1 Axes>,
#  <AxesSubplot:xlabel='$x$', ylabel='$y$'>)

# %%
np.save(figsrc_dir / scan_name / f"{scan_name}_labels_8.1_30.npy", clustering.labels.labels)

# %%
r = 5
c = 30

neighbours = [np.where(d < r)[0] for d in distances]
for n in neighbours:
    n.sort()
        
neighbours_clustering = cluster.prepare_clustering(
    neighbours,
    preparation_hook=cluster.prepare_neighbourhoods,
    **neighbours_sorted_recipe
)

neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
clustering._labels = neighbours_clustering._labels

# %%
fig, ax = plt.subplots()
clustering.evaluate(ax=ax, ax_props={"xlim": (-180, 180), "ylim": (-180, 180), "aspect": "equal"})
# Out:
# (<Figure size 600x370.828 with 1 Axes>,
#  <AxesSubplot:xlabel='$x$', ylabel='$y$'>)

# %%
np.save(figsrc_dir / scan_name / f"{scan_name}_labels_5_30.npy", clustering.labels.labels)

# %% [markdown]
# ##### Hierarchical manual

# %%
r = 20
c = 30

h_clustering = cluster.prepare_clustering(data)
h_clustering._metric = _types.MetricExtEuclideanPeriodicReduced(
    np.array([360, 360], dtype=float)
)

h_clustering.fit(r, c, member_cutoff=20, v=False)
h_clustering.isolate()

# %%
for sub_clustering, (r, c) in [(h_clustering.children[1], (5, 30)), (h_clustering.children[2], (8.1, 30))]:
    sub_clustering.fit(r, c, member_cutoff=20, v=False)
    sub_clustering.isolate()

# %%
fig, (pie_ax, tree_ax) = plt.subplots(1, 2, figsize=(3.33, 3.33 / 1.618 / 2))
h_clustering.pie(
    ax=pie_ax,
    pie_props={
        "radius": 0.6,
        "wedgeprops": dict(width=0.6, edgecolor="k")
    }
)

graph = h_clustering.to_nx_DiGraph(ignore={0})

shortened_labels = {}
for key in graph.nodes.keys():
    shortened_labels[key] = key.rsplit(".", 1)[-1]
    
colors = cycler.by_key()["color"]
depth_counter = defaultdict(int)

node_colors = []
for node in graph.nodes:
    depth = len(node)
    node_colors.append(colors[depth_counter[depth]])
    depth_counter[depth] += 1
    
plot.plot_graph_sugiyama_straight(
    graph,
    ax=tree_ax,
    pos_props = {
        "source": "1",
        },
    draw_props={
        "labels": shortened_labels,
        "with_labels": True,
        "node_shape": "s",
        "edgecolors": "k",
        "node_size": 100,
        "node_color": node_colors,  # [cycler.by_key()["color"][int(shortened_labels[node]) - 1] for node in graph.nodes ],
        "font_size": 8,
    }
)
fig.tight_layout()
fig.savefig(figsrc_dir / scan_name / f"{scan_name}_pie_tree.png")

# %%
h_clustering.reel()
h_clustering.labels.sort_by_size()

# %%
fig, ax = plt.subplots()
h_clustering.evaluate(ax=ax, ax_props={"xlim": (-180, 180), "ylim": (-180, 180), "aspect": "equal"})
# Out:
# (<Figure size 600x370.828 with 1 Axes>,
#  <AxesSubplot:xlabel='$x$', ylabel='$y$'>)

# %%
ax.yaxis.label.set_r

# %%
np.save(figsrc_dir / scan_name / f"{scan_name}_labels_reeled.npy", h_clustering.labels.labels)

# %% [markdown]
# ## Peptide (TICA)

# %%
scan_name = "tica"

# %%
# The test data
data_path = data_dir / "6a5j/projections/tica_500_4.npy"
data = [p[::10, :] for p in np.load(data_path)]

# %%
data_concatened = np.concatenate(data)
n_points = data_concatened.shape[0] 

distances = pairwise_distances(data_concatened[::2])

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(2, 1))
ax1.scatter(
    *data_concatened[:, :2].T,
    s=0.5,
)
ax2.scatter(
    *data_concatened[:, 2:].T,
    s=0.5,
)
plt.tight_layout(w_pad=1)

# %% [markdown]
# ### Checks

# %%
fig, ax = plt.subplots()
_ = plot.plot_histogram(ax, distances.flatten(), maxima=True, maxima_props={"order": 5})

# %%
h, binmids = calc_histogram(distances.flatten(), save=True, base_name=figsrc_dir / f"{scan_name}_dist")

# %%
print("Min: ", distances[distances > 0].min())
print("Max: ", distances.max())
# Out:
# Min:  0.005043478
# Max:  6.638115

# %%
r_array, min_n, max_n, mean_n = calc_n_neighbours_per_radius(
    distances, save=True, base_name=figsrc_dir / f"{scan_name}"
    )

# %%
plot_n_neighbours_per_radius(
    r_array, min_n * 2, max_n * 2, mean_n * 2,
    0.3, n_points
)

# %% [markdown]
# ### Scan

# %%
scan_name = "tica"
clustering = CLUSTERING_MAP[scan_name] = cluster.prepare_clustering(data)

# %%
for r in tqdm(np.arange(0.01, 1.01, 0.01)):
    neighbours = helper.compute_neighbours(data_concatened, r, sort=True)
    neighbours_clustering = cluster.prepare_clustering(
        neighbours,
        preparation_hook=cluster.prepare_neighbourhoods,
        **neighbours_sorted_recipe
    )

    for c in range(251):
        neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
        clustering.summary.append(neighbours_clustering.summary[-1])

# %%
for record in clustering.summary:
    record.radius_cutoff = round(record.radius_cutoff, 5)

# %% [markdown]
# ### Plots

# %%
scan_name = "tica"
clustering = CLUSTERING_MAP[scan_name]

# %% [markdown]
# #### Time

# %%
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="execution_time",
    contour_props={
        "levels": 50,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax)
colorbar.set_label("time / s")

ax.set_xlim(0.01, 1.0)
ax.set_ylim(0, 250)
# Out:
# (0.0, 250.0)

# %% [markdown]
# #### Noise level

# %%
# Noise level
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_noise",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("noise / %")
ax.set_xlim(0.01, 1.0)
ax.set_ylim(0, 250)
# Out:
# (0.0, 250.0)

# %% [markdown]
# #### Largest cluster

# %%
# Largest cluster
fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="ratio_largest",
    contour_props={
        "levels": np.arange(0, 1.01, 0.01),
        "vmin": 0,
        "vmax": 1,
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=(0, 0.5, 1))
colorbar.set_label("largest / %")
ax.set_xlim(0.01, 1.0)
ax.set_ylim(0, 250)
# Out:
# (0.0, 250.0)

# %% [markdown]
# #### Number of clusters

# %%
# Number of clusters
show_n = 10

fig, ax = plt.subplots()
contour = clustering.summarize(
    ax=ax,
    quantity="n_clusters",
    contour_props={
        "levels": np.arange(-0.5, show_n + 1.5, 1),
        "vmin": 0,
        "vmax": show_n,
        "extend": "max"
    }
)[2][0]
colorbar = fig.colorbar(mappable=contour, ax=ax, ticks=range(0, show_n + 1, 2))
colorbar.set_label("# clusters")
ax.set_xlim(0.01, 1.0)
ax.set_ylim(0, 250)
# Out:
# (0.0, 250.0)

# %% [markdown]
# #### Evaluation

# %%
scan_name = "tica"
clustering = cluster.prepare_clustering(data)

# %%
r = 1
c = 40

neighbours = helper.compute_neighbours(data_concatened, r, sort=True)
neighbours_clustering = cluster.prepare_clustering(
    neighbours,
    preparation_hook=cluster.prepare_neighbourhoods,
    **neighbours_sorted_recipe
)

neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
clustering._labels = neighbours_clustering._labels

# %%
fig, Ax = plt.subplots(
    1, 2,
    figsize=(
        mpl.rcParams["figure.figsize"][0] * 1.5,
        mpl.rcParams["figure.figsize"][1],
    )
)
for axi, dim in enumerate(range(0, 4, 2)):
    clustering.evaluate(
        ax=Ax[axi],
        dim=(dim, dim + 1),
        ax_props={"xlabel": None, "ylabel": None, "xticks": (), "yticks": ()}
    )

# %%
r = 0.75
c = 40

neighbours = helper.compute_neighbours(data_concatened, r, sort=True)
neighbours_clustering = cluster.prepare_clustering(
    neighbours,
    preparation_hook=cluster.prepare_neighbourhoods,
    **neighbours_sorted_recipe
)

neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
clustering._labels = neighbours_clustering._labels

# %%
fig, Ax = plt.subplots(
    1, 2,
    figsize=(
        mpl.rcParams["figure.figsize"][0] * 1.5,
        mpl.rcParams["figure.figsize"][1],
    )
)
for axi, dim in enumerate(range(0, 4, 2)):
    clustering.evaluate(
        ax=Ax[axi],
        dim=(dim, dim + 1),
        ax_props={"xlabel": None, "ylabel": None, "xticks": (), "yticks": ()}
    )

# %%
r = 0.5
c = 40

neighbours = helper.compute_neighbours(data_concatened, r, sort=True)
neighbours_clustering = cluster.prepare_clustering(
    neighbours,
    preparation_hook=cluster.prepare_neighbourhoods,
    **neighbours_sorted_recipe
)

neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
clustering._labels = neighbours_clustering._labels

# %%
fig, Ax = plt.subplots(
    1, 2,
    figsize=(
        mpl.rcParams["figure.figsize"][0] * 1.5,
        mpl.rcParams["figure.figsize"][1],
    )
)
for axi, dim in enumerate(range(0, 4, 2)):
    clustering.evaluate(
        ax=Ax[axi],
        dim=(dim, dim + 1),
        ax_props={"xlabel": None, "ylabel": None, "xticks": (), "yticks": ()}
    )

# %%
r = 0.25
c = 40

neighbours = helper.compute_neighbours(data_concatened, r, sort=True)
neighbours_clustering = cluster.prepare_clustering(
    neighbours,
    preparation_hook=cluster.prepare_neighbourhoods,
    **neighbours_sorted_recipe
)

neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
clustering._labels = neighbours_clustering._labels

# %%
fig, Ax = plt.subplots(
    1, 2,
    figsize=(
        mpl.rcParams["figure.figsize"][0] * 1.5,
        mpl.rcParams["figure.figsize"][1],
    )
)
for axi, dim in enumerate(range(0, 4, 2)):
    clustering.evaluate(
        ax=Ax[axi],
        dim=(dim, dim + 1),
        ax_props={"xlabel": None, "ylabel": None, "xticks": (), "yticks": ()}
    )

# %%
r = 0.15
c = 40

neighbours = helper.compute_neighbours(data_concatened, r, sort=True)
neighbours_clustering = cluster.prepare_clustering(
    neighbours,
    preparation_hook=cluster.prepare_neighbourhoods,
    **neighbours_sorted_recipe
)

neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
clustering._labels = neighbours_clustering._labels

# %%
fig, Ax = plt.subplots(
    1, 2,
    figsize=(
        mpl.rcParams["figure.figsize"][0] * 1.5,
        mpl.rcParams["figure.figsize"][1],
    )
)
for axi, dim in enumerate(range(0, 4, 2)):
    clustering.evaluate(
        ax=Ax[axi],
        dim=(dim, dim + 1),
        ax_props={"xlabel": None, "ylabel": None, "xticks": (), "yticks": ()}
    )

# %%
r = 0.1
c = 40

neighbours = helper.compute_neighbours(data_concatened, r, sort=True)
neighbours_clustering = cluster.prepare_clustering(
    neighbours,
    preparation_hook=cluster.prepare_neighbourhoods,
    **neighbours_sorted_recipe
)

neighbours_clustering.fit(r, c, member_cutoff=20, v=False)
clustering._labels = neighbours_clustering._labels

# %%
fig, Ax = plt.subplots(
    1, 2,
    figsize=(
        mpl.rcParams["figure.figsize"][0] * 1.5,
        mpl.rcParams["figure.figsize"][1],
    )
)
for axi, dim in enumerate(range(0, 4, 2)):
    clustering.evaluate(
        ax=Ax[axi],
        dim=(dim, dim + 1),
        ax_props={"xlabel": None, "ylabel": None, "xticks": (), "yticks": ()}
    )

# %% [markdown]
# #### Hierarchical semi-automatic

# %%
h_clustering = cluster.prepare_clustering(
    data,
    **neighbours_sorted_alternative_recipe
)
h_clustering._neighbours_getter.build_tree(h_clustering._input_data)

# %%
r = [0.5, 0.25]
c = 40

h_clustering.fit_hierarchical(r, c, member_cutoff=20)

# %%
fig, Ax = plt.subplots(
    1, 2,
    figsize=(
        mpl.rcParams["figure.figsize"][0] * 1.5,
        mpl.rcParams["figure.figsize"][1],
    )
)
for axi, dim in enumerate(range(0, 4, 2)):
    h_clustering.evaluate(
        ax=Ax[axi],
        dim=(dim, dim + 1),
        ax_props={"xlabel": None, "ylabel": None, "xticks": (), "yticks": ()}
    )

# %%
fig, ax = plt.subplots(figsize=(3.33, 3.33))
h_clustering.pie(ax=ax)
# Out:
# (<Figure size 999x999 with 1 Axes>, <AxesSubplot:>)

# %%
fig, ax = plt.subplots(figsize=(3.33, 1.5))
h_clustering.tree(
    ax=ax,
    pos_props={"x_spacing": 10, "y_spacing": 0.01},
    draw_props={"node_size": 100, "font_size": 6},
    
)
# Out:
# (<Figure size 999x450 with 1 Axes>, <AxesSubplot:>)

# %%
def trim_trivial(clustering):
    if clustering._labels is None:
        return
    
    if len(clustering._labels.mapping) == 1:
        clustering._labels = None
        return
    
    for child in clustering._children.values():
        trim_trivial(child)
    
    return

# %%
trim_trivial(h_clustering)

# %%
h_clustering.reel()

# %%
fig, Ax = plt.subplots(
    1, 2,
    figsize=(
        mpl.rcParams["figure.figsize"][0] * 1.5,
        mpl.rcParams["figure.figsize"][1],
    )
)
for axi, dim in enumerate(range(0, 4, 2)):
    h_clustering.evaluate(
        ax=Ax[axi],
        dim=(dim, dim + 1),
        ax_props={"xlabel": None, "ylabel": None, "xticks": (), "yticks": ()}
    )
